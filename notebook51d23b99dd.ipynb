# %% [markdown]
# # ColdSite-DTI — configurable binary grid (Kaggle)
#
# One notebook for any of the four baseline/ours models, on either dataset, over any subset
# of the four split types -- so two Kaggle accounts (or two commits of the same account) can
# each own a share of the work without ever training the same cell twice.
#
# | model | role |
# |---|---|
# | DeepDTA | accuracy anchor (no attention, never audited) |
# | ColdSite-DTI | our model |
# | HyperAttentionDTI | published model under audit |
# | MolTrans | published model under audit (deferred until this notebook existed) |
#
# **Why binary.** DeepDTA, HyperAttentionDTI and MolTrans only predict binding / non-binding
# in this project's recipe, so the audit table can only compare models on one metric --
# AUROC -- if every model does the same task. A pair counts as binding at
# **pKd >= threshold** (`BINARY_THRESHOLD` in `src/model/dataset.py`: DAVIS 7.0, KIBA 12.1).
#
# ## Before you run
#
# | Setting | Value |
# |---|---|
# | Accelerator | **GPU** (T4 x2 if available -- more GPUs, more parallel splits) |
# | Internet | **On** |
# | Environment | **Pin to original** |
# | How to run | **Save Version -> Save & Run All (Commit)** |
# | Settings cell | edit `DATASET`, `MODELS`, `SPLIT_SUBSET`, `SEEDS` below -- see presets there |
#
# ## The loop you will repeat -- read this
#
# Every commit starts in a **fresh, empty container**. Finished cells do not carry over by
# themselves. So:
#
# 1. **First commit:** leave `RESTORE_FROM = None` and commit.
# 2. When it finishes: open that version -> **Output** -> download the results zip, and
#    upload it as a Kaggle **Dataset** (name it so you know which account/model/dataset it
#    is -- e.g. `coldsite-moltrans-davis-results`).
# 3. **Every later commit:** attach that dataset (Add Input), set `RESTORE_FROM` in the
#    restore cell, and commit. Finished cells are skipped; interrupted ones are retrained.
# 4. After each commit, add the new output to the dataset (**New Version** of it), so the
#    next restore has everything.
#
# **The notebook stops itself at 11 hours.** Kaggle ends a commit at 12, and a commit cut off
# mid-cell may not save its output. A cell stopped mid-training is retrained on the next
# commit.
#
# **MolTrans checkpoints are big** -- about 250 MB each (vs. ~2.5 MB for the other three
# models; its decoder has a 78,192 -> 512 linear layer). A 12-cell MolTrans grid is ~3 GB.
# Plan the restore-dataset size and the Drive backup accordingly.

# %% [markdown]
# ## 1. Settings — the only cell you should need to edit

# %%
# ============================================================================
# SETTINGS
# ============================================================================

DATASET = 'davis'                 # 'davis' | 'kiba'
MODELS = ['moltrans']             # any subset of: 'deepdta', 'coldsite_dti', 'hyperattentiondti', 'moltrans'
SPLIT_SUBSET = ['random', 'cold_drug', 'cold_target', 'cold_pair']  # which split types THIS run trains
SEEDS = [2, 3]

# --- presets, for reference -- delete or ignore whichever you are not using ------------
# Account 2, MolTrans on DAVIS (first job -- all four splits, nobody else is training them):
#   DATASET = 'davis'; MODELS = ['moltrans']
#   SPLIT_SUBSET = ['random', 'cold_drug', 'cold_target', 'cold_pair']
#
# Account 2, MolTrans on KIBA (after DAVIS is done -- HALF the splits; agree the other
# half with account 1 first, see CLAUDE.md):
#   DATASET = 'kiba'; MODELS = ['moltrans']
#   SPLIT_SUBSET = ['random', 'cold_drug']                      # example half
#
# Account 1, once the DAVIS 36-grid is 36/36 -- KIBA, the three DAVIS-grid models, the
# OTHER half of the splits:
#   DATASET = 'kiba'; MODELS = ['deepdta', 'coldsite_dti', 'hyperattentiondti']
#   SPLIT_SUBSET = ['cold_target', 'cold_pair']                 # the half account 2 is not training
# -----------------------------------------------------------------------------------------

ALL_SPLITS = ['random', 'cold_drug', 'cold_target', 'cold_pair']
KNOWN_MODELS = ['deepdta', 'coldsite_dti', 'hyperattentiondti', 'moltrans']

assert DATASET in ('davis', 'kiba'), DATASET
assert MODELS and all(m in KNOWN_MODELS for m in MODELS), \
    f'MODELS must be a non-empty subset of {KNOWN_MODELS}, got {MODELS}'
assert SPLIT_SUBSET and all(s in ALL_SPLITS for s in SPLIT_SUBSET), \
    f'SPLIT_SUBSET must be a non-empty subset of {ALL_SPLITS}, got {SPLIT_SUBSET}'
assert SEEDS, 'SEEDS must not be empty'

TOTAL_CELLS = len(MODELS) * len(SPLIT_SUBSET) * len(SEEDS)
print(f'{DATASET} | models: {", ".join(MODELS)} | splits: {", ".join(SPLIT_SUBSET)} | seeds: {SEEDS}')
print(f'{TOTAL_CELLS} cells this run ({len(MODELS)} model(s) x {len(SPLIT_SUBSET)} split(s) x {len(SEEDS)} seed(s))')
# Out:
# davis | models: moltrans | splits: random, cold_drug, cold_target, cold_pair | seeds: [2, 3]
# 8 cells this run (1 model(s) x 4 split(s) x 2 seed(s))

# %% [markdown]
# ## 2. Check the GPU(s)

# %%
import time
START = time.time()          # the 11-hour self-stop is measured from here

import torch

assert torch.cuda.is_available(), 'No CUDA. Settings -> Accelerator -> GPU.'
N_GPU = torch.cuda.device_count()
for i in range(N_GPU):
    p = torch.cuda.get_device_properties(i)
    print(f'GPU {i}: {p.name}, {p.total_memory/1e9:.1f} GB')
print('torch  :', torch.__version__)

# Measured peak memory on a 1000-residue protein (STATUS.md), from the DAVIS 36-grid:
#   ColdSite-DTI  batch 64 -> 8.7 GB, 16 -> 2.3 GB
#   HyperAttentionDTI  batch 32 -> ~5 GB; 8 x accum 4 is the same effective batch
#   DeepDTA  batch 256 -> 0.7 GB
#   MolTrans  not yet profiled on a full split -- stays at the vendored batch size (16)
#   rather than guessing a larger one on a bigger GPU.
big = torch.cuda.get_device_properties(0).total_memory / 1e9 >= 14
COLDSITE_BATCH = 64 if big else 16
HAT_BATCH, HAT_ACCUM = (32, 1) if big else (8, 4)
DEEPDTA_BATCH = 256
MOLTRANS_BATCH = 16
print(f'batches: ColdSite {COLDSITE_BATCH}, HAT {HAT_BATCH}x{HAT_ACCUM}, '
      f'DeepDTA {DEEPDTA_BATCH}, MolTrans {MOLTRANS_BATCH}')
# Out:
# GPU 0: Tesla T4, 15.6 GB
# GPU 1: Tesla T4, 15.6 GB
# torch  : 2.10.0+cu128
# batches: ColdSite 64, HAT 32x1, DeepDTA 256, MolTrans 16

# %% [markdown]
# ## 3. Clone the repo
#
# Pinned to `main` on the fork. If this run trains MolTrans, the cell also refuses to
# continue on a checkout that predates `src/model/train_moltrans.py` -- that file has to be
# pushed to `origin/main` before Kaggle can clone it.

# %%
import os

REPO = 'https://github.com/Mahim56207/ColdSite-DTI_New.git'
WORK = '/kaggle/working'
SRC  = f'{WORK}/ColdSite-DTI_New'

if not os.path.exists(SRC):
    # !git clone --branch main {REPO} {SRC}
os.chdir(SRC)
# !git pull origin main
# !pip install -q tabulate subword-nmt

import importlib, src.model.dataset as _ds
importlib.reload(_ds)
assert hasattr(_ds, 'BINARY_THRESHOLD'), (
    'This checkout predates the binary-label fix -- ColdSite-DTI would crash. '
    'Re-run this cell so git pull fetches main.')
if 'moltrans' in MODELS:
    assert os.path.exists('src/model/train_moltrans.py'), (
        'This checkout has no src/model/train_moltrans.py -- push that commit to '
        'origin/main before running MolTrans here, then re-run this cell.')

RESULTS = f'{WORK}/results'
os.makedirs(RESULTS, exist_ok=True)
print()
# !git log --oneline -1
print('results ->', RESULTS)
# Out:
# Cloning into '/kaggle/working/ColdSite-DTI_New'...
# remote: Enumerating objects: 1022, done.
# remote: Counting objects: 100% (276/276), done.
# remote: Compressing objects: 100% (200/200), done.
# remote: Total 1022 (delta 162), reused 174 (delta 76), pack-reused 746 (from 1)
# Receiving objects: 100% (1022/1022), 184.94 MiB | 26.81 MiB/s, done.
# Resolving deltas: 100% (534/534), done.
# From https://github.com/Mahim56207/ColdSite-DTI_New
#  * branch            main       -> FETCH_HEAD
# Already up to date.
#
# b66d142 (HEAD -> main, origin/main, origin/HEAD) Warn when two seeds of a cell come out identical
# results -> /kaggle/working/results

# %% [markdown]
# ## 4. Fetch the DeepDTA source files
#
# `build_splits` needs these for both datasets regardless of which models this run trains.

# %%
BASE = 'https://raw.githubusercontent.com/hkmztrk/DeepDTA/master/data'
for ds in ('davis', 'kiba'):
    os.makedirs(f'src/data/baselines/deepdta/data/{ds}', exist_ok=True)
    for fname in ('ligands_can.txt', 'proteins.txt', 'Y'):
        target = f'src/data/baselines/deepdta/data/{ds}/{fname}'
        if not os.path.exists(target):
            # !curl -sL {BASE}/{ds}/{fname} -o {target}
# !python -m src.data.load_data
# Out:
# davis: 30056 measured pairs, 68 unique drugs, 442 unique targets, Y range [5.000, 10.796]
# kiba: 118254 measured pairs, 2111 unique drugs, 229 unique targets, Y range [0.000, 17.200]

# %% [markdown]
# ## 5. Build the splits — and verify they match
#
# Every cell in this project has to come from the same splits, whichever account or model
# trains it. The counts below were verified on a MacBook, on Colab and on Kaggle.

# %%
# !python -m src.data.build_splits 2>&1 | grep -E 'davis|kiba|leakage'

import pandas as pd

EXPECTED = {
    'davis': {
        'random':      (21039, 3006, 6011),
        'cold_drug':   (21658, 2652, 5746),
        'cold_target': (21080, 2992, 5984),
        'cold_pair':   (15190,  264, 1144),
    },
    'kiba': {
        'random':      (82778, 11825, 23651),
        'cold_drug':   (83807, 12073, 22374),
        'cold_target': (85452, 10701, 22101),
        'cold_pair':   (58041,  1334,  4375),
    },
}

problems = []
for split in ALL_SPLITS:
    expected = EXPECTED[DATASET][split]
    got = tuple(len(pd.read_csv(f'data/splits/{DATASET}/{split}/{part}.csv'))
                for part in ('train', 'valid', 'test'))
    marker = 'OK' if got == expected else 'MISMATCH'
    flag = '  <- this run trains it' if split in SPLIT_SUBSET else ''
    if got != expected:
        problems.append(f'{split}: expected {expected}, got {got}')
    print(f"{split:12s} {str(got):26s} {marker}{flag}")
assert not problems, f'{DATASET} splits differ from the rest of the project:\n  ' + '\n  '.join(problems)
print(f'\n{DATASET} splits match. Safe to train.')
# Out:
# === Building splits for davis ===
# Saved data/splits/davis/random/  train=21039  valid=3006  test=6011
# Saved data/splits/davis/cold_drug/  train=21658  valid=2652  test=5746
# Saved data/splits/davis/cold_target/  train=21080  valid=2992  test=5984
# Saved data/splits/davis/cold_pair/  train=15190  valid=264  test=1144
# cold_drug: no leakage across train/valid/test -- OK
# cold_target: no leakage across train/valid/test -- OK
# cold_pair: no leakage across train/valid/test -- OK
# === Building splits for kiba ===
# Saved data/splits/kiba/random/  train=82778  valid=11825  test=23651
# Saved data/splits/kiba/cold_drug/  train=83807  valid=12073  test=22374
# Saved data/splits/kiba/cold_target/  train=85452  valid=10701  test=22101
# Saved data/splits/kiba/cold_pair/  train=58041  valid=1334  test=4375
# cold_drug: no leakage across train/valid/test -- OK
# cold_target: no leakage across train/valid/test -- OK
# cold_pair: no leakage across train/valid/test -- OK
# random       (21039, 3006, 6011)        OK  <- this run trains it
# cold_drug    (21658, 2652, 5746)        OK  <- this run trains it
# cold_target  (21080, 2992, 5984)        OK  <- this run trains it
# cold_pair    (15190, 264, 1144)         OK  <- this run trains it
#
# davis splits match. Safe to train.

# %% [markdown]
# ## 6. Restore results from a previous commit
#
# `None` on the first commit. After that, attach the dataset holding the previous output and
# put its path here. Only model files are copied, and nothing already present is
# overwritten.

# %%
import shutil, glob

# '/kaggle/input' -- searches every attached input. Kaggle does not always mount a
# dataset at /kaggle/input/<name> (2026-09-12: that path failed; this one restored 65).
RESTORE_FROM = None

if RESTORE_FROM:
    assert os.path.isdir(RESTORE_FROM), f'not a directory: {RESTORE_FROM}'
    copied = skipped = 0
    for src in glob.glob(f'{RESTORE_FROM}/**/*', recursive=True):
        name = os.path.basename(src)
        if not name.endswith(('.pt', '_results.json', '_history.json')):
            continue
        dst = os.path.join(RESULTS, name)
        if os.path.exists(dst):
            skipped += 1
            continue
        shutil.copy2(src, dst)
        copied += 1
    print(f'restored {copied} file(s), left {skipped} already present')
else:
    print('RESTORE_FROM is None -- starting from an empty results folder.')
# Out:
# RESTORE_FROM is None -- starting from an empty results folder.

# %% [markdown]
# ## 7. The runner
#
# Each GPU works through its own queue of commands in order; the GPUs run in parallel. This
# run's `SPLIT_SUBSET` is divided across the available GPUs; each GPU trains every model in
# `MODELS`, cheapest first, over its share of splits. Every line is prefixed with where it
# comes from -- GPU, model, split, seed and cell number -- so a line never needs scrolling
# back to place. Each finished cell gets a `✓` line with its test AUROC and the running total,
# and every 10 minutes a `STATUS` line shows every GPU at once: search the log for `STATUS`.
#
# At the 11-hour mark it stops launching new work and ends anything still running, so the
# commit can save.

# %%
import subprocess, threading, glob, json, re
from src.model.checkpoint_naming import checkpoint_path, results_path, run_tag

DEADLINE = START + 11 * 3600
STATUS_EVERY = 600          # seconds between STATUS lines

splits_list = list(SPLIT_SUBSET)
SHARE = {str(g): splits_list[g::N_GPU] for g in range(N_GPU)}
SHARE = {g: s for g, s in SHARE.items() if s}   # drop a GPU with nothing to do

MODEL_NAME = {'src.model.train_deepdta': 'DeepDTA', 'src.model.run_grid': 'ColdSite',
              'src.model.train_hyperattentiondti': 'HAT', 'src.model.train_moltrans': 'MolTrans'}
HEADER = re.compile(r'^\w+/(\w+)/seed(\d+)\s*$')          # run_grid: a cell starts
SKIPPED = re.compile(r'^\[skip\] \w+/(\w+)/seed(\d+)')     # run_grid: a cell was done
EPOCH = re.compile(r'^\s*(?:epoch|Epoch)\s+(\d+)')
SAVED = re.compile(r'Saved -> (\S+_results\.json)')


def hours_left():
    return (DEADLINE - time.time()) / 3600


def cells_done():
    done = 0
    for model in MODELS:
        for split in SPLIT_SUBSET:
            for seed in SEEDS:
                tag = run_tag(DATASET, split, 'binary', seed)
                if os.path.exists(results_path(RESULTS, tag, model=model)):
                    done += 1
    return done


def same_as_other_seed(results_file):
    """Another seed of this model and split with exactly the same test metrics means the
    seed never reached training -- MolTrans's vendored import reseeded torch with 1, so
    its three DAVIS seeds were one run three times (2026-09-13)."""
    try:
        mine = json.load(open(results_file))['test_metrics']
        for other in glob.glob(re.sub(r'_seed\d+', '_seed[0-9]', results_file)):
            if other != results_file and json.load(open(other))['test_metrics'] == mine:
                return (f'SEEDS IDENTICAL: same test metrics as {os.path.basename(other)} '
                        f'-- is --seed reaching training? Stop and check before going on.')
    except Exception:
        return None
    return None

def _arg(cmd, flag):
    return cmd[cmd.index(flag) + 1] if flag in cmd else '-'


def _cells_in(cmd):
    if cmd[3] == 'src.model.run_grid':
        return len(_arg(cmd, '--splits').split(',')) * len(_arg(cmd, '--seeds').split(','))
    return 1


def run_parallel(queues, label):
    """queues: {gpu: [command, ...]}. Returns True if the deadline cut it short."""
    current, state = {}, {'deadline': False}
    where = {g: {'model': '-', 'split': '-', 'seed': '-', 'epoch': '-', 'cell': 0,
                 'total': sum(_cells_in(c) for c in q)} for g, q in queues.items()}

    def tag(g):
        w = where[g]
        return f"[GPU{g} {w['model']} {w['split']} s{w['seed']} · cell {w['cell']}/{w['total']}]"

    def begin_cell(g, split, seed):
        where[g].update(split=split, seed=seed, epoch='-')
        where[g]['cell'] += 1

    def worker(gpu, commands):
        env = {**os.environ, 'CUDA_VISIBLE_DEVICES': gpu, 'PYTHONUNBUFFERED': '1'}
        with open(f'{WORK}/{label}_gpu{gpu}.log', 'a') as log:
            for cmd in commands:
                if time.time() > DEADLINE:
                    return
                module = cmd[3]
                where[gpu]['model'] = MODEL_NAME.get(module, module)
                if module != 'src.model.run_grid':          # one command = one cell
                    begin_cell(gpu, _arg(cmd, '--split'), _arg(cmd, '--seed'))
                proc = subprocess.Popen(cmd, env=env, stdout=subprocess.PIPE,
                                        stderr=subprocess.STDOUT, text=True, bufsize=1)
                current[gpu] = proc
                for line in proc.stdout:
                    if module == 'src.model.run_grid':      # follow run_grid's own cells
                        m = HEADER.match(line) or SKIPPED.match(line)
                        if m:
                            begin_cell(gpu, m.group(1), m.group(2))
                    m = EPOCH.match(line)
                    if m:
                        where[gpu]['epoch'] = m.group(1)
                    print(f'{tag(gpu)} {line}', end='', flush=True)
                    log.write(line)
                    log.flush()
                    m = SAVED.search(line)
                    if m:
                        try:
                            auc = json.load(open(m.group(1)))['test_metrics'].get('auroc')
                            auc = f'{auc:.4f}'
                        except Exception:
                            auc = '?'
                        print(f'  ✓ {tag(gpu)} finished -- test AUROC {auc}   '
                              f'[{cells_done()}/{TOTAL_CELLS} cells complete]', flush=True)
                        warning = same_as_other_seed(m.group(1))
                        if warning:
                            print(f'  !! {tag(gpu)} {warning}', flush=True)
                code_ = proc.wait()
                if code_ != 0 and not state['deadline']:
                    print(f'{tag(gpu)} !! exited {code_}: {" ".join(cmd[3:])}', flush=True)

    threads = [threading.Thread(target=worker, args=(g, q), daemon=True)
               for g, q in queues.items()]
    for t in threads:
        t.start()
    last_status = 0.0
    while any(t.is_alive() for t in threads):
        if time.time() - last_status >= STATUS_EVERY:
            last_status = time.time()
            parts = [f"GPU{g}: {w['model']} {w['split']} s{w['seed']} "
                     f"cell {w['cell']}/{w['total']} epoch {w['epoch']}"
                     for g, w in where.items()]
            print(f"\n=== STATUS {time.strftime('%H:%M')} | " + ' | '.join(parts)
                  + f' | {cells_done()}/{TOTAL_CELLS} complete | {hours_left():.1f} h left ===\n',
                  flush=True)
        if time.time() > DEADLINE and not state['deadline']:
            state['deadline'] = True
            print('\n*** 11-hour mark: stopping so this commit can save its output. '
                  'Unfinished cells are retrained next commit. ***\n', flush=True)
            for proc in list(current.values()):
                if proc.poll() is None:
                    proc.terminate()
        time.sleep(15)
    return state['deadline']


def deepdta_cmd(split, seed):
    return ['python', '-u', '-m', 'src.model.train_deepdta',
            '--split-dir', f'data/splits/{DATASET}/{split}', '--dataset', DATASET,
            '--split', split, '--task', 'binary', '--seed', str(seed),
            '--batch-size', str(DEEPDTA_BATCH), '--min-epochs', '10', '--epochs', '100',
            '--patience', '10',     # DeepDTA's own; DAVIS was trained with it
            '--checkpoint-dir', RESULTS, '--results-dir', RESULTS, '--skip-if-done']


def coldsite_cmd(splits):
    # patience is not a train.py flag; ColdSite-DTI's is fixed at 15 in run_training
    return ['python', '-u', '-m', 'src.model.run_grid', '--datasets', DATASET,
            '--splits', ','.join(splits), '--seeds', ','.join(map(str, SEEDS)),
            '--task', 'binary', '--epochs', '100', '--min-epochs', '10',
            '--batch-size', str(COLDSITE_BATCH), '--results-dir', RESULTS]


def hat_cmd(split, seed):
    return ['python', '-u', '-m', 'src.model.train_hyperattentiondti',
            '--split-dir', f'data/splits/{DATASET}/{split}', '--dataset', DATASET,
            '--split', split, '--seed', str(seed),
            '--batch-size', str(HAT_BATCH), '--accum-steps', str(HAT_ACCUM),
            '--patience', '15',
            '--min-epochs', '10', '--epochs', '100',
            '--checkpoint-dir', RESULTS, '--results-dir', RESULTS, '--skip-if-done']


def moltrans_cmd(split, seed):
    return ['python', '-u', '-m', 'src.model.train_moltrans',
            '--split-dir', f'data/splits/{DATASET}/{split}', '--dataset', DATASET,
            '--split', split, '--seed', str(seed),
            '--batch-size', str(MOLTRANS_BATCH), '--min-epochs', '10', '--epochs', '100',
            '--patience', '15',
            '--checkpoint-dir', RESULTS, '--results-dir', RESULTS, '--skip-if-done']


# Cheapest / fastest-signal model first, when it is part of this run.
MODEL_ORDER = ['deepdta', 'moltrans', 'coldsite_dti', 'hyperattentiondti']


def build_queue(splits):
    queue = []
    for model in MODEL_ORDER:
        if model not in MODELS:
            continue
        if model == 'deepdta':
            queue += [deepdta_cmd(split, seed) for split in splits for seed in SEEDS]
        elif model == 'coldsite_dti':
            queue.append(coldsite_cmd(splits))
        elif model == 'hyperattentiondti':
            queue += [hat_cmd(split, seed) for split in splits for seed in SEEDS]
        elif model == 'moltrans':
            queue += [moltrans_cmd(split, seed) for split in splits for seed in SEEDS]
    return queue


for gpu, splits in SHARE.items():
    print(f'GPU {gpu} -> {", ".join(splits)}  ({", ".join(MODELS)})')
print(f'{hours_left():.1f} h left before the self-stop')
# Out:
# GPU 0 -> random, cold_target  (moltrans)
# GPU 1 -> cold_drug, cold_pair  (moltrans)
# 11.0 h left before the self-stop

# %% [markdown]
# ## 8. Launch

# %%
if hours_left() < 0.5:
    print(f'Skipped: only {hours_left():.1f} h left. Commit again with the restore cell set.')
else:
    queues = {gpu: build_queue(splits) for gpu, splits in SHARE.items()}
    cut_short = run_parallel(queues, 'grid')
    print('\n' + ('CUT SHORT by the deadline -- commit again with RESTORE_FROM set'
                  if cut_short else 'Queue finished on every GPU.'))
# Out:
# === STATUS 01:47 | GPU0: MolTrans random s2 cell 1/4 epoch - | GPU1: - - s- cell 0/4 epoch - | 0/8 complete | 11.0 h left ===
#
# [GPU0 MolTrans random s2 · cell 1/4]   train  21,039 pairs  8.5% positive  <- data/splits/davis/random/train.csv
# [GPU1 MolTrans cold_drug s2 · cell 1/4]   train  21,658 pairs  9.4% positive  <- data/splits/davis/cold_drug/train.csv
# [GPU0 MolTrans random s2 · cell 1/4]   valid   3,006 pairs  8.3% positive  <- data/splits/davis/random/valid.csv
# [GPU1 MolTrans cold_drug s2 · cell 1/4]   valid   2,652 pairs  4.9% positive  <- data/splits/davis/cold_drug/valid.csv
# [GPU0 MolTrans random s2 · cell 1/4]   test    6,011 pairs  7.7% positive  <- data/splits/davis/random/test.csv
# [GPU0 MolTrans random s2 · cell 1/4]
# [GPU0 MolTrans random s2 · cell 1/4]   device        cuda (Tesla T4, 14.6 GB)
# [GPU0 MolTrans random s2 · cell 1/4]   batch size    16 (vendored: 16)
# [GPU1 MolTrans cold_drug s2 · cell 1/4]   test    5,746 pairs  6.0% positive  <- data/splits/davis/cold_drug/test.csv
# [GPU1 MolTrans cold_drug s2 · cell 1/4]
# [GPU1 MolTrans cold_drug s2 · cell 1/4]   device        cuda (Tesla T4, 14.6 GB)
# [GPU1 MolTrans cold_drug s2 · cell 1/4]   batch size    16 (vendored: 16)
# [GPU0 MolTrans random s2 · cell 1/4]
# [GPU1 MolTrans cold_drug s2 · cell 1/4]
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 20/1314 loss 0.6147
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 20/1353 loss 0.6449
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 40/1314 loss 0.5694
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 40/1353 loss 0.5867
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 60/1314 loss 0.5378
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 60/1353 loss 0.5508
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 80/1314 loss 0.5073
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 80/1353 loss 0.5240
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 100/1314 loss 0.4856
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 100/1353 loss 0.5059
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 120/1314 loss 0.4718
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 120/1353 loss 0.4905
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 140/1314 loss 0.4592
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 140/1353 loss 0.4747
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 160/1314 loss 0.4479
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 160/1353 loss 0.4613
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 180/1314 loss 0.4393
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 180/1353 loss 0.4545
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 200/1314 loss 0.4314
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 200/1353 loss 0.4480
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 220/1314 loss 0.4220
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 220/1353 loss 0.4413
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 240/1314 loss 0.4165
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 240/1353 loss 0.4312
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 260/1314 loss 0.4080
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 260/1353 loss 0.4240
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 280/1314 loss 0.4007
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 280/1353 loss 0.4162
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 300/1314 loss 0.3950
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 300/1353 loss 0.4125
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 320/1314 loss 0.3888
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 320/1353 loss 0.4075
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 340/1314 loss 0.3823
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 340/1353 loss 0.3997
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 360/1314 loss 0.3765
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 360/1353 loss 0.3936
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 380/1314 loss 0.3732
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 380/1353 loss 0.3896
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 400/1314 loss 0.3713
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 400/1353 loss 0.3848
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 420/1314 loss 0.3691
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 420/1353 loss 0.3822
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 440/1314 loss 0.3642
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 440/1353 loss 0.3794
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 460/1314 loss 0.3602
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 460/1353 loss 0.3755
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 480/1314 loss 0.3550
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 500/1314 loss 0.3520
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 480/1353 loss 0.3719
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 520/1314 loss 0.3495
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 500/1353 loss 0.3670
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 540/1314 loss 0.3482
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 520/1353 loss 0.3621
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 560/1314 loss 0.3442
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 540/1353 loss 0.3585
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 580/1314 loss 0.3401
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 560/1353 loss 0.3566
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 600/1314 loss 0.3379
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 620/1314 loss 0.3344
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 580/1353 loss 0.3538
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 640/1314 loss 0.3314
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 600/1353 loss 0.3523
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 660/1314 loss 0.3304
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 620/1353 loss 0.3505
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 680/1314 loss 0.3282
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 640/1353 loss 0.3491
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 700/1314 loss 0.3278
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 660/1353 loss 0.3477
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 720/1314 loss 0.3264
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 680/1353 loss 0.3454
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 740/1314 loss 0.3257
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 700/1353 loss 0.3437
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 760/1314 loss 0.3237
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 720/1353 loss 0.3405
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 780/1314 loss 0.3228
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 740/1353 loss 0.3384
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 800/1314 loss 0.3211
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 820/1314 loss 0.3181
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 760/1353 loss 0.3352
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 840/1314 loss 0.3163
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 780/1353 loss 0.3328
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 860/1314 loss 0.3145
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 800/1353 loss 0.3310
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 880/1314 loss 0.3146
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 820/1353 loss 0.3302
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 900/1314 loss 0.3132
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 840/1353 loss 0.3303
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 920/1314 loss 0.3117
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 860/1353 loss 0.3290
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 940/1314 loss 0.3109
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 880/1353 loss 0.3281
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 960/1314 loss 0.3107
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 980/1314 loss 0.3099
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 900/1353 loss 0.3263
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 1000/1314 loss 0.3085
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 920/1353 loss 0.3258
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 1020/1314 loss 0.3067
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 940/1353 loss 0.3239
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 1040/1314 loss 0.3069
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 960/1353 loss 0.3224
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 1060/1314 loss 0.3062
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 980/1353 loss 0.3213
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 1080/1314 loss 0.3045
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 1000/1353 loss 0.3203
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 1100/1314 loss 0.3034
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 1020/1353 loss 0.3207
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 1120/1314 loss 0.3031
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 1140/1314 loss 0.3027
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 1040/1353 loss 0.3194
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 1160/1314 loss 0.3018
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 1060/1353 loss 0.3177
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 1180/1314 loss 0.3000
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 1080/1353 loss 0.3168
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 1200/1314 loss 0.2987
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 1100/1353 loss 0.3162
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 1220/1314 loss 0.2977
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 1120/1353 loss 0.3159
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 1240/1314 loss 0.2966
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 1140/1353 loss 0.3145
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 1260/1314 loss 0.2953
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 1160/1353 loss 0.3136
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 1280/1314 loss 0.2956
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 1300/1314 loss 0.2947
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 train batch 1314/1314 loss 0.2945
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 1180/1353 loss 0.3124
# [GPU0 MolTrans random s2 · cell 1/4]
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 valid batch 20/188 loss 0.2286
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 valid batch 40/188 loss 0.2510
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 valid batch 60/188 loss 0.2315
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 1200/1353 loss 0.3105
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 valid batch 80/188 loss 0.2193
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 valid batch 100/188 loss 0.2200
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 valid batch 120/188 loss 0.2279
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 1220/1353 loss 0.3098
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 valid batch 140/188 loss 0.2345
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 valid batch 160/188 loss 0.2274
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 valid batch 180/188 loss 0.2274
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 1 valid batch 188/188 loss 0.2262
# [GPU0 MolTrans random s2 · cell 1/4]   epoch   1 train 0.2945 val 0.2262 auroc 0.8368 auprc 0.3660 accuracy 0.9168
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 1240/1353 loss 0.3091
# [GPU0 MolTrans random s2 · cell 1/4]
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 1260/1353 loss 0.3085
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 20/1314 loss 0.2156
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 1280/1353 loss 0.3074
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 40/1314 loss 0.2304
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 60/1314 loss 0.2448
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 1300/1353 loss 0.3066
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 80/1314 loss 0.2507
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 1320/1353 loss 0.3053
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 1340/1353 loss 0.3046
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 train batch 1353/1353 loss 0.3034
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 100/1314 loss 0.2405
# [GPU1 MolTrans cold_drug s2 · cell 1/4]
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 valid batch 20/166 loss 0.1497
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 120/1314 loss 0.2329
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 valid batch 40/166 loss 0.1743
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 valid batch 60/166 loss 0.1690
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 valid batch 80/166 loss 0.1866
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 140/1314 loss 0.2238
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 valid batch 100/166 loss 0.2062
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 valid batch 120/166 loss 0.2145
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 valid batch 140/166 loss 0.2025
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 160/1314 loss 0.2273
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 valid batch 160/166 loss 0.1903
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 1 valid batch 166/166 loss 0.1866
# [GPU1 MolTrans cold_drug s2 · cell 1/4]   epoch   1 train 0.3034 val 0.1866 auroc 0.6850 auprc 0.2130 accuracy 0.9510
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 180/1314 loss 0.2296
# [GPU1 MolTrans cold_drug s2 · cell 1/4]
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 200/1314 loss 0.2324
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 20/1353 loss 0.2780
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 220/1314 loss 0.2306
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 40/1353 loss 0.2451
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 240/1314 loss 0.2327
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 60/1353 loss 0.2372
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 260/1314 loss 0.2308
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 80/1353 loss 0.2499
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 280/1314 loss 0.2279
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 100/1353 loss 0.2511
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 300/1314 loss 0.2250
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 320/1314 loss 0.2266
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 120/1353 loss 0.2467
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 340/1314 loss 0.2232
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 140/1353 loss 0.2482
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 360/1314 loss 0.2282
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 160/1353 loss 0.2493
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 380/1314 loss 0.2262
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 180/1353 loss 0.2497
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 400/1314 loss 0.2270
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 200/1353 loss 0.2436
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 420/1314 loss 0.2268
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 220/1353 loss 0.2474
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 440/1314 loss 0.2258
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 240/1353 loss 0.2458
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 460/1314 loss 0.2264
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 260/1353 loss 0.2460
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 480/1314 loss 0.2275
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 500/1314 loss 0.2260
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 280/1353 loss 0.2456
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 520/1314 loss 0.2276
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 300/1353 loss 0.2506
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 540/1314 loss 0.2273
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 320/1353 loss 0.2511
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 560/1314 loss 0.2286
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 340/1353 loss 0.2489
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 580/1314 loss 0.2277
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 360/1353 loss 0.2501
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 600/1314 loss 0.2268
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 380/1353 loss 0.2496
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 620/1314 loss 0.2260
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 400/1353 loss 0.2489
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 640/1314 loss 0.2264
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 660/1314 loss 0.2256
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 420/1353 loss 0.2485
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 680/1314 loss 0.2265
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 440/1353 loss 0.2504
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 700/1314 loss 0.2260
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 460/1353 loss 0.2504
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 720/1314 loss 0.2262
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 480/1353 loss 0.2520
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 740/1314 loss 0.2259
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 500/1353 loss 0.2517
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 760/1314 loss 0.2268
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 520/1353 loss 0.2517
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 780/1314 loss 0.2267
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 540/1353 loss 0.2516
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 800/1314 loss 0.2276
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 820/1314 loss 0.2285
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 560/1353 loss 0.2496
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 840/1314 loss 0.2285
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 580/1353 loss 0.2493
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 860/1314 loss 0.2286
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 600/1353 loss 0.2490
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 880/1314 loss 0.2301
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 620/1353 loss 0.2491
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 900/1314 loss 0.2295
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 640/1353 loss 0.2477
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 920/1314 loss 0.2296
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 660/1353 loss 0.2469
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 940/1314 loss 0.2289
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 680/1353 loss 0.2485
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 960/1314 loss 0.2287
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 980/1314 loss 0.2289
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 700/1353 loss 0.2497
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 1000/1314 loss 0.2290
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 720/1353 loss 0.2488
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 1020/1314 loss 0.2286
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 740/1353 loss 0.2490
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 1040/1314 loss 0.2291
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 760/1353 loss 0.2470
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 1060/1314 loss 0.2296
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 780/1353 loss 0.2458
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 1080/1314 loss 0.2297
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 800/1353 loss 0.2457
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 1100/1314 loss 0.2301
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 820/1353 loss 0.2452
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 1120/1314 loss 0.2308
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 840/1353 loss 0.2443
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 1140/1314 loss 0.2310
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 1160/1314 loss 0.2313
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 860/1353 loss 0.2447
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 1180/1314 loss 0.2318
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 880/1353 loss 0.2460
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 1200/1314 loss 0.2315
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 900/1353 loss 0.2462
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 1220/1314 loss 0.2321
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 920/1353 loss 0.2466
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 1240/1314 loss 0.2325
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 940/1353 loss 0.2465
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 1260/1314 loss 0.2333
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 960/1353 loss 0.2464
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 1280/1314 loss 0.2329
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 1300/1314 loss 0.2329
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 train batch 1314/1314 loss 0.2332
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 980/1353 loss 0.2456
# [GPU0 MolTrans random s2 · cell 1/4]
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 valid batch 20/188 loss 0.2167
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 valid batch 40/188 loss 0.2241
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 valid batch 60/188 loss 0.2108
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 1000/1353 loss 0.2450
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 valid batch 80/188 loss 0.1993
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 valid batch 100/188 loss 0.1996
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 valid batch 120/188 loss 0.2036
#
# === STATUS 01:57 | GPU0: MolTrans random s2 cell 1/4 epoch 2 | GPU1: MolTrans cold_drug s2 cell 1/4 epoch 2 | 0/8 complete | 10.8 h left ===
#
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 1020/1353 loss 0.2442
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 valid batch 140/188 loss 0.2099
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 valid batch 160/188 loss 0.2043
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 valid batch 180/188 loss 0.2039
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 2 valid batch 188/188 loss 0.2037
# [GPU0 MolTrans random s2 · cell 1/4]   epoch   2 train 0.2332 val 0.2037 auroc 0.8665 auprc 0.4286 accuracy 0.9225
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 1040/1353 loss 0.2445
# [GPU0 MolTrans random s2 · cell 1/4]
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 1060/1353 loss 0.2447
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 20/1314 loss 0.2009
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 1080/1353 loss 0.2437
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 40/1314 loss 0.2097
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 60/1314 loss 0.2210
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 1100/1353 loss 0.2433
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 80/1314 loss 0.2235
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 1120/1353 loss 0.2429
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 100/1314 loss 0.2243
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 1140/1353 loss 0.2436
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 120/1314 loss 0.2184
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 1160/1353 loss 0.2429
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 140/1314 loss 0.2153
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 1180/1353 loss 0.2430
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 160/1314 loss 0.2161
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 1200/1353 loss 0.2423
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 180/1314 loss 0.2169
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 1220/1353 loss 0.2424
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 200/1314 loss 0.2190
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 1240/1353 loss 0.2423
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 220/1314 loss 0.2187
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 240/1314 loss 0.2210
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 1260/1353 loss 0.2421
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 260/1314 loss 0.2237
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 1280/1353 loss 0.2417
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 280/1314 loss 0.2253
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 1300/1353 loss 0.2415
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 300/1314 loss 0.2258
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 1320/1353 loss 0.2406
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 320/1314 loss 0.2262
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 1340/1353 loss 0.2396
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 train batch 1353/1353 loss 0.2391
# [GPU1 MolTrans cold_drug s2 · cell 1/4]
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 340/1314 loss 0.2238
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 valid batch 20/166 loss 0.1341
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 valid batch 40/166 loss 0.1658
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 valid batch 60/166 loss 0.1615
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 360/1314 loss 0.2231
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 valid batch 80/166 loss 0.1827
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 valid batch 100/166 loss 0.1977
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 valid batch 120/166 loss 0.2108
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 380/1314 loss 0.2244
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 valid batch 140/166 loss 0.1950
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 valid batch 160/166 loss 0.1811
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 2 valid batch 166/166 loss 0.1773
# [GPU1 MolTrans cold_drug s2 · cell 1/4]   epoch   2 train 0.2391 val 0.1773 auroc 0.6646 auprc 0.3445 accuracy 0.9510
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 400/1314 loss 0.2246
# [GPU1 MolTrans cold_drug s2 · cell 1/4]
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 420/1314 loss 0.2239
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 20/1353 loss 0.2131
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 440/1314 loss 0.2231
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 40/1353 loss 0.1924
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 460/1314 loss 0.2216
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 480/1314 loss 0.2191
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 60/1353 loss 0.1933
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 500/1314 loss 0.2192
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 80/1353 loss 0.1995
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 520/1314 loss 0.2191
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 100/1353 loss 0.2015
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 540/1314 loss 0.2197
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 120/1353 loss 0.2073
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 560/1314 loss 0.2183
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 140/1353 loss 0.2124
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 580/1314 loss 0.2200
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 160/1353 loss 0.2145
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 600/1314 loss 0.2198
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 180/1353 loss 0.2151
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 620/1314 loss 0.2205
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 200/1353 loss 0.2179
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 640/1314 loss 0.2203
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 660/1314 loss 0.2212
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 220/1353 loss 0.2165
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 680/1314 loss 0.2202
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 240/1353 loss 0.2138
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 700/1314 loss 0.2186
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 260/1353 loss 0.2162
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 720/1314 loss 0.2183
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 280/1353 loss 0.2168
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 740/1314 loss 0.2183
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 300/1353 loss 0.2159
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 760/1314 loss 0.2168
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 320/1353 loss 0.2184
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 780/1314 loss 0.2166
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 340/1353 loss 0.2191
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 800/1314 loss 0.2171
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 820/1314 loss 0.2155
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 360/1353 loss 0.2205
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 840/1314 loss 0.2136
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 380/1353 loss 0.2200
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 860/1314 loss 0.2144
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 400/1353 loss 0.2205
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 880/1314 loss 0.2143
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 420/1353 loss 0.2184
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 900/1314 loss 0.2133
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 440/1353 loss 0.2191
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 920/1314 loss 0.2117
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 460/1353 loss 0.2240
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 940/1314 loss 0.2113
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 480/1353 loss 0.2257
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 960/1314 loss 0.2114
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 980/1314 loss 0.2115
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 500/1353 loss 0.2267
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 1000/1314 loss 0.2116
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 520/1353 loss 0.2268
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 1020/1314 loss 0.2114
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 540/1353 loss 0.2261
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 1040/1314 loss 0.2119
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 560/1353 loss 0.2264
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 1060/1314 loss 0.2112
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 580/1353 loss 0.2265
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 1080/1314 loss 0.2101
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 600/1353 loss 0.2268
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 1100/1314 loss 0.2108
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 620/1353 loss 0.2260
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 1120/1314 loss 0.2104
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 1140/1314 loss 0.2104
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 640/1353 loss 0.2264
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 1160/1314 loss 0.2103
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 660/1353 loss 0.2262
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 1180/1314 loss 0.2105
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 680/1353 loss 0.2252
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 1200/1314 loss 0.2111
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 700/1353 loss 0.2246
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 1220/1314 loss 0.2119
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 720/1353 loss 0.2260
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 1240/1314 loss 0.2117
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 740/1353 loss 0.2259
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 1260/1314 loss 0.2115
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 760/1353 loss 0.2263
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 1280/1314 loss 0.2113
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 1300/1314 loss 0.2114
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 train batch 1314/1314 loss 0.2112
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 780/1353 loss 0.2249
# [GPU0 MolTrans random s2 · cell 1/4]
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 valid batch 20/188 loss 0.2161
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 valid batch 40/188 loss 0.2392
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 valid batch 60/188 loss 0.2252
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 800/1353 loss 0.2247
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 valid batch 80/188 loss 0.2159
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 valid batch 100/188 loss 0.2143
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 valid batch 120/188 loss 0.2147
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 820/1353 loss 0.2239
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 valid batch 140/188 loss 0.2213
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 valid batch 160/188 loss 0.2165
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 valid batch 180/188 loss 0.2160
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 3 valid batch 188/188 loss 0.2164
# [GPU0 MolTrans random s2 · cell 1/4]   epoch   3 train 0.2112 val 0.2164 auroc 0.8612 auprc 0.4349 accuracy 0.9102
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 840/1353 loss 0.2245
# [GPU0 MolTrans random s2 · cell 1/4]
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 860/1353 loss 0.2247
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 20/1314 loss 0.1840
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 880/1353 loss 0.2249
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 40/1314 loss 0.1904
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 60/1314 loss 0.2001
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 900/1353 loss 0.2240
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 80/1314 loss 0.1816
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 920/1353 loss 0.2234
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 100/1314 loss 0.1804
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 940/1353 loss 0.2247
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 120/1314 loss 0.1802
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 960/1353 loss 0.2239
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 140/1314 loss 0.1821
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 980/1353 loss 0.2239
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 160/1314 loss 0.1818
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 1000/1353 loss 0.2240
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 180/1314 loss 0.1854
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 1020/1353 loss 0.2248
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 200/1314 loss 0.1942
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 220/1314 loss 0.1938
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 1040/1353 loss 0.2241
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 240/1314 loss 0.1956
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 1060/1353 loss 0.2249
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 260/1314 loss 0.1942
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 1080/1353 loss 0.2246
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 280/1314 loss 0.1989
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 1100/1353 loss 0.2257
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 300/1314 loss 0.1967
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 1120/1353 loss 0.2267
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 320/1314 loss 0.1981
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 1140/1353 loss 0.2267
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 340/1314 loss 0.1962
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 1160/1353 loss 0.2272
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 360/1314 loss 0.1969
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 1180/1353 loss 0.2274
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 380/1314 loss 0.1973
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 400/1314 loss 0.1964
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 1200/1353 loss 0.2270
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 420/1314 loss 0.1966
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 1220/1353 loss 0.2263
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 440/1314 loss 0.1967
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 1240/1353 loss 0.2255
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 460/1314 loss 0.1985
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 1260/1353 loss 0.2253
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 480/1314 loss 0.1984
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 1280/1353 loss 0.2262
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 500/1314 loss 0.1982
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 1300/1353 loss 0.2259
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 520/1314 loss 0.1986
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 1320/1353 loss 0.2252
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 540/1314 loss 0.1992
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 1340/1353 loss 0.2251
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 train batch 1353/1353 loss 0.2254
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 560/1314 loss 0.2005
# [GPU1 MolTrans cold_drug s2 · cell 1/4]
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 valid batch 20/166 loss 0.1289
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 valid batch 40/166 loss 0.1576
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 580/1314 loss 0.2014
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 valid batch 60/166 loss 0.1624
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 valid batch 80/166 loss 0.1820
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 600/1314 loss 0.2011
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 valid batch 100/166 loss 0.1964
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 valid batch 120/166 loss 0.2046
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 valid batch 140/166 loss 0.1940
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 valid batch 160/166 loss 0.1841
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 3 valid batch 166/166 loss 0.1816
# [GPU1 MolTrans cold_drug s2 · cell 1/4]   epoch   3 train 0.2254 val 0.1816 auroc 0.7223 auprc 0.3117 accuracy 0.9510
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 620/1314 loss 0.1999
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 640/1314 loss 0.1998
# [GPU1 MolTrans cold_drug s2 · cell 1/4]
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 660/1314 loss 0.1989
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 4 train batch 20/1353 loss 0.2348
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 680/1314 loss 0.1987
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 4 train batch 40/1353 loss 0.2055
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 700/1314 loss 0.1984
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 4 train batch 60/1353 loss 0.2123
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 720/1314 loss 0.1990
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 4 train batch 80/1353 loss 0.2253
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 740/1314 loss 0.1996
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 4 train batch 100/1353 loss 0.2237
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 760/1314 loss 0.1986
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 4 train batch 120/1353 loss 0.2273
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 780/1314 loss 0.1975
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 800/1314 loss 0.1985
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 4 train batch 140/1353 loss 0.2302
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 820/1314 loss 0.1991
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 4 train batch 160/1353 loss 0.2303
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 840/1314 loss 0.1996
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 4 train batch 180/1353 loss 0.2304
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 860/1314 loss 0.1999
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 4 train batch 200/1353 loss 0.2273
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 880/1314 loss 0.1999
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 4 train batch 220/1353 loss 0.2238
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 900/1314 loss 0.1997
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 4 train batch 240/1353 loss 0.2256
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 920/1314 loss 0.1986
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 4 train batch 260/1353 loss 0.2212
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 940/1314 loss 0.1993
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 4 train batch 280/1353 loss 0.2234
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 960/1314 loss 0.1996
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 980/1314 loss 0.2001
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 4 train batch 300/1353 loss 0.2217
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 1000/1314 loss 0.1996
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 4 train batch 320/1353 loss 0.2230
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 1020/1314 loss 0.2003
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 4 train batch 340/1353 loss 0.2228
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 1040/1314 loss 0.2000
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 4 train batch 360/1353 loss 0.2209
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 1060/1314 loss 0.2000
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 4 train batch 380/1353 loss 0.2200
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 1080/1314 loss 0.2004
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 4 train batch 400/1353 loss 0.2197
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 1100/1314 loss 0.1999
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 4 train batch 420/1353 loss 0.2218
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 1120/1314 loss 0.1993
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 1140/1314 loss 0.1989
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 4 train batch 440/1353 loss 0.2199
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 1160/1314 loss 0.1992
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 4 train batch 460/1353 loss 0.2177
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 1180/1314 loss 0.1999
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 4 train batch 480/1353 loss 0.2163
# [GPU0 MolTrans random s2 · cell 1/4]     epoch 4 train batch 1200/1314 loss 0.2003
# [GPU1 MolTrans cold_drug s2 · cell 1/4]     epoch 4 train batch 500/1353 loss 0.2172
# ...
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 60/1317 loss 0.0429
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 80/1317 loss 0.0385
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 100/1317 loss 0.0345
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 120/1317 loss 0.0336
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 140/1317 loss 0.0337
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 160/1317 loss 0.0329
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 180/1317 loss 0.0317
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 200/1317 loss 0.0326
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 220/1317 loss 0.0322
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 240/1317 loss 0.0326
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 260/1317 loss 0.0320
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 280/1317 loss 0.0318
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 300/1317 loss 0.0313
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 320/1317 loss 0.0315
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 340/1317 loss 0.0311
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 360/1317 loss 0.0322
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 380/1317 loss 0.0317
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 400/1317 loss 0.0314
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 420/1317 loss 0.0309
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 440/1317 loss 0.0311
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 460/1317 loss 0.0310
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 480/1317 loss 0.0311
#
# === STATUS 10:08 | GPU0: MolTrans cold_target s3 cell 4/4 epoch 25 | GPU1: MolTrans cold_pair s3 cell 4/4 epoch 28 | 7/8 complete | 2.7 h left ===
#
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 500/1317 loss 0.0306
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 520/1317 loss 0.0305
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 540/1317 loss 0.0307
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 560/1317 loss 0.0302
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 580/1317 loss 0.0313
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 600/1317 loss 0.0310
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 620/1317 loss 0.0310
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 640/1317 loss 0.0311
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 660/1317 loss 0.0321
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 680/1317 loss 0.0324
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 700/1317 loss 0.0324
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 720/1317 loss 0.0321
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 740/1317 loss 0.0323
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 760/1317 loss 0.0325
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 780/1317 loss 0.0331
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 800/1317 loss 0.0333
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 820/1317 loss 0.0335
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 840/1317 loss 0.0334
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 860/1317 loss 0.0334
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 880/1317 loss 0.0338
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 900/1317 loss 0.0335
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 920/1317 loss 0.0337
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 940/1317 loss 0.0337
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 960/1317 loss 0.0342
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 980/1317 loss 0.0343
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 1000/1317 loss 0.0344
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 1020/1317 loss 0.0343
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 1040/1317 loss 0.0341
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 1060/1317 loss 0.0340
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 1080/1317 loss 0.0339
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 1100/1317 loss 0.0342
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 1120/1317 loss 0.0339
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 1140/1317 loss 0.0341
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 1160/1317 loss 0.0342
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 1180/1317 loss 0.0344
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 1200/1317 loss 0.0349
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 1220/1317 loss 0.0357
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 1240/1317 loss 0.0355
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 1260/1317 loss 0.0355
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 1280/1317 loss 0.0355
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 1300/1317 loss 0.0357
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 train batch 1317/1317 loss 0.0354
# [GPU0 MolTrans cold_target s3 · cell 4/4]
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 valid batch 20/187 loss 0.2746
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 valid batch 40/187 loss 0.2369
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 valid batch 60/187 loss 0.2905
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 valid batch 80/187 loss 0.3172
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 valid batch 100/187 loss 0.3228
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 valid batch 120/187 loss 0.3414
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 valid batch 140/187 loss 0.3446
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 valid batch 160/187 loss 0.3657
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 valid batch 180/187 loss 0.3757
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 25 valid batch 187/187 loss 0.3790
# [GPU0 MolTrans cold_target s3 · cell 4/4]   epoch  25 train 0.0354 val 0.3790 auroc 0.7894 auprc 0.3212 accuracy 0.9301
# [GPU0 MolTrans cold_target s3 · cell 4/4]
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 20/1317 loss 0.0305
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 40/1317 loss 0.0383
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 60/1317 loss 0.0406
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 80/1317 loss 0.0385
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 100/1317 loss 0.0395
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 120/1317 loss 0.0389
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 140/1317 loss 0.0369
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 160/1317 loss 0.0374
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 180/1317 loss 0.0385
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 200/1317 loss 0.0383
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 220/1317 loss 0.0362
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 240/1317 loss 0.0343
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 260/1317 loss 0.0337
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 280/1317 loss 0.0343
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 300/1317 loss 0.0347
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 320/1317 loss 0.0355
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 340/1317 loss 0.0345
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 360/1317 loss 0.0344
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 380/1317 loss 0.0336
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 400/1317 loss 0.0338
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 420/1317 loss 0.0333
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 440/1317 loss 0.0333
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 460/1317 loss 0.0334
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 480/1317 loss 0.0326
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 500/1317 loss 0.0328
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 520/1317 loss 0.0324
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 540/1317 loss 0.0325
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 560/1317 loss 0.0334
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 580/1317 loss 0.0332
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 600/1317 loss 0.0330
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 620/1317 loss 0.0329
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 640/1317 loss 0.0328
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 660/1317 loss 0.0326
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 680/1317 loss 0.0329
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 700/1317 loss 0.0328
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 720/1317 loss 0.0328
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 740/1317 loss 0.0332
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 760/1317 loss 0.0333
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 780/1317 loss 0.0334
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 800/1317 loss 0.0335
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 820/1317 loss 0.0332
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 840/1317 loss 0.0332
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 860/1317 loss 0.0336
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 880/1317 loss 0.0335
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 900/1317 loss 0.0333
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 920/1317 loss 0.0336
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 940/1317 loss 0.0332
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 960/1317 loss 0.0333
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 980/1317 loss 0.0333
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 1000/1317 loss 0.0334
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 1020/1317 loss 0.0337
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 1040/1317 loss 0.0339
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 1060/1317 loss 0.0342
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 1080/1317 loss 0.0344
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 1100/1317 loss 0.0345
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 1120/1317 loss 0.0345
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 1140/1317 loss 0.0345
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 1160/1317 loss 0.0346
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 1180/1317 loss 0.0346
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 1200/1317 loss 0.0352
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 1220/1317 loss 0.0354
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 1240/1317 loss 0.0354
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 1260/1317 loss 0.0353
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 1280/1317 loss 0.0353
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 1300/1317 loss 0.0352
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 train batch 1317/1317 loss 0.0360
# [GPU0 MolTrans cold_target s3 · cell 4/4]
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 valid batch 20/187 loss 0.3161
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 valid batch 40/187 loss 0.2603
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 valid batch 60/187 loss 0.3085
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 valid batch 80/187 loss 0.3249
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 valid batch 100/187 loss 0.3465
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 valid batch 120/187 loss 0.3682
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 valid batch 140/187 loss 0.3692
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 valid batch 160/187 loss 0.3973
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 valid batch 180/187 loss 0.4168
# [GPU0 MolTrans cold_target s3 · cell 4/4]     epoch 26 valid batch 187/187 loss 0.4235
# [GPU0 MolTrans cold_target s3 · cell 4/4]   epoch  26 train 0.0360 val 0.4235 auroc 0.7487 auprc 0.3060 accuracy 0.9301
# [GPU0 MolTrans cold_target s3 · cell 4/4]   early stop at epoch 26 (best 11)
# [GPU0 MolTrans cold_target s3 · cell 4/4]
# [GPU0 MolTrans cold_target s3 · cell 4/4]     test batch 20/374 loss 0.2217
# [GPU0 MolTrans cold_target s3 · cell 4/4]     test batch 40/374 loss 0.2086
# [GPU0 MolTrans cold_target s3 · cell 4/4]     test batch 60/374 loss 0.1652
# [GPU0 MolTrans cold_target s3 · cell 4/4]     test batch 80/374 loss 0.1498
# [GPU0 MolTrans cold_target s3 · cell 4/4]     test batch 100/374 loss 0.1787
# [GPU0 MolTrans cold_target s3 · cell 4/4]     test batch 120/374 loss 0.1570
# [GPU0 MolTrans cold_target s3 · cell 4/4]     test batch 140/374 loss 0.1690
# [GPU0 MolTrans cold_target s3 · cell 4/4]     test batch 160/374 loss 0.1615
# [GPU0 MolTrans cold_target s3 · cell 4/4]     test batch 180/374 loss 0.1800
# [GPU0 MolTrans cold_target s3 · cell 4/4]     test batch 200/374 loss 0.1684
# [GPU0 MolTrans cold_target s3 · cell 4/4]     test batch 220/374 loss 0.1705
# [GPU0 MolTrans cold_target s3 · cell 4/4]     test batch 240/374 loss 0.1818
# [GPU0 MolTrans cold_target s3 · cell 4/4]     test batch 260/374 loss 0.1798
# [GPU0 MolTrans cold_target s3 · cell 4/4]     test batch 280/374 loss 0.1798
# [GPU0 MolTrans cold_target s3 · cell 4/4]     test batch 300/374 loss 0.1768
# [GPU0 MolTrans cold_target s3 · cell 4/4]     test batch 320/374 loss 0.1957
# [GPU0 MolTrans cold_target s3 · cell 4/4]     test batch 340/374 loss 0.1996
# [GPU0 MolTrans cold_target s3 · cell 4/4]     test batch 360/374 loss 0.1975
# [GPU0 MolTrans cold_target s3 · cell 4/4]     test batch 374/374 loss 0.2005
# [GPU0 MolTrans cold_target s3 · cell 4/4]
# [GPU0 MolTrans cold_target s3 · cell 4/4] Test metrics: {
# [GPU0 MolTrans cold_target s3 · cell 4/4]   "auroc": 0.8755721478891412,
# [GPU0 MolTrans cold_target s3 · cell 4/4]   "auprc": 0.5422798747626707,
# [GPU0 MolTrans cold_target s3 · cell 4/4]   "accuracy": 0.9386697860962567
# [GPU0 MolTrans cold_target s3 · cell 4/4] }
# [GPU0 MolTrans cold_target s3 · cell 4/4] Saved -> /kaggle/working/results/davis_cold_target_binary_seed3_moltrans_results.json
#   ✓ [GPU0 MolTrans cold_target s3 · cell 4/4] finished -- test AUROC 0.8756   [8/8 cells complete]
#
# Queue finished on every GPU.

# %% [markdown]
# ## 9. What landed
#
# A cell counts as complete only when both its checkpoint and its results file exist. A
# checkpoint alone is an interrupted cell, and the next commit retrains it.

# %%
import statistics as st

complete = interrupted = 0
print(f"{'model':18s} {'split':12s} {'cells':>7s}   AUROC mean +- sd")
for model in MODELS:
    for split in SPLIT_SUBSET:
        values = []
        for seed in SEEDS:
            ckpt = checkpoint_path(RESULTS, DATASET, split, 'binary', seed, model=model)
            res = results_path(RESULTS, run_tag(DATASET, split, 'binary', seed), model=model)
            if os.path.exists(ckpt) and os.path.exists(res):
                complete += 1
                values.append(json.load(open(res))['test_metrics']['auroc'])
            elif os.path.exists(ckpt):
                interrupted += 1
        spread = (f'{st.mean(values):.4f} +- {st.stdev(values):.4f}' if len(values) > 1
                  else f'{values[0]:.4f}' if values else '--')
        flag = ('   <- SEEDS IDENTICAL: --seed is not reaching training'
                if len(values) > 1 and len(set(values)) == 1 else '')
        print(f'{model:18s} {split:12s} {len(values):>3d}/{len(SEEDS):<3d}   {spread}{flag}')

RUN_COMPLETE = complete == TOTAL_CELLS
print(f'\ncomplete    : {complete} / {TOTAL_CELLS}')
print(f'interrupted : {interrupted}  (retrained next commit)')
print(f'time left   : {hours_left():.1f} h')
print("\nALL DONE for this run's settings." if RUN_COMPLETE else
      '\nNot done yet: download the output, update the restore dataset, commit again with RESTORE_FROM set.')
# Out:
# model              split          cells   AUROC mean +- sd
# moltrans           random         2/2     0.9232 +- 0.0030
# moltrans           cold_drug      2/2     0.6932 +- 0.0185
# moltrans           cold_target    2/2     0.8770 +- 0.0021
# moltrans           cold_pair      2/2     0.5578 +- 0.0135
#
# complete    : 8 / 8
# interrupted : 0  (retrained next commit)
# time left   : 2.5 h
#
# ALL DONE for this run's settings.

# %% [markdown]
# ## 10. Take the results with you
#
# Everything in `/kaggle/working` is saved as this version's output. The zip is the easy
# download. Add its contents to your restore dataset (as a new version) before the next
# commit, and keep a copy in Google Drive.

# %%
ZIP_NAME = f'{DATASET}_{"_".join(MODELS)}_results.zip'
# !cd {WORK} && rm -f {ZIP_NAME} && zip -qr {ZIP_NAME} results
print(f'{WORK}/{ZIP_NAME}  --  download from the Output panel')
# Out:
# /kaggle/working/davis_moltrans_results.zip  --  download from the Output panel
