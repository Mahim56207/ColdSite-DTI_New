# %% [markdown]
# # ColdSite-DTI — the 36-run audit grid (DAVIS, binary, Kaggle T4 x2)
#
# **3 models x 4 splits x 3 seeds = 36 runs**, DAVIS, binary task. This is the scientific
# spine of the paper as scoped in STATUS.md on 2026-08-18: every number in the ladder, the
# faithfulness figure, the Holm-corrected audit table and the non-kinase control comes from
# these checkpoints.
#
# | model | role | cells |
# |---|---|---|
# | DeepDTA | accuracy anchor (no attention, never audited) | 12 |
# | ColdSite-DTI | our model | 12 |
# | HyperAttentionDTI | the published model under audit | 12 |
#
# **Why binary.** HyperAttentionDTI and MolTrans only predict binding / non-binding, so the
# audit table can only compare models on one metric -- AUROC -- if every model does the same
# task. A pair counts as binding at **DAVIS pKd >= 7.0**, DeepDTA's published threshold,
# defined once in `src/model/dataset.py` and shared by all three trainers. About 8% of DAVIS
# pairs bind, so accuracy is ~0.92 for a model that always says "no": read AUROC, not accuracy.
#
# The 12 DAVIS *regression* cells trained earlier do not count here -- different task.
#
# ## Before you run
#
# | Setting | Value |
# |---|---|
# | Accelerator | **GPU T4 x2** |
# | Internet | **On** |
# | Environment | **Pin to original** |
# | How to run | **Save Version -> Save & Run All (Commit)** |
#
# ## The loop you will repeat -- read this
#
# Every commit starts in a **fresh, empty container**. Finished cells do not carry over by
# themselves (the DAVIS regression run proved it: a second commit retrained all twelve). So:
#
# 1. **First commit:** leave `RESTORE_FROM = None` and commit.
# 2. When it finishes: open that version -> **Output** -> download `results`, and upload it
#    as a Kaggle **Dataset** (e.g. `coldsite-grid36-results`).
# 3. **Every later commit:** attach that dataset (Add Input), set `RESTORE_FROM` in cell 5,
#    and commit. Finished cells are skipped; interrupted ones are retrained.
# 4. After each commit, add the new output to the dataset (**New Version** of it), so the
#    next restore has everything.
#
# **The notebook stops itself at 11 hours.** Kaggle ends a commit at 12, and a commit cut off
# mid-cell may not save its output. Stopping at 11 lets the commit finish cleanly and save
# whatever completed. A cell stopped mid-training is retrained on the next commit.
#
# ## What to expect
#
# | stage | per GPU | notes |
# |---|---|---|
# | 1. DeepDTA, 12 cells | ~0.5-1 h | fast; its AUROC is the sanity gate |
# | 2. ColdSite-DTI, 6 cells per GPU | unknown until one finishes | DAVIS regression cells took 1-3.5 h each |
# | 2. HyperAttentionDTI, 6 cells per GPU | ~3.5-9.5 h | STATUS.md estimate |
#
# Realistically **2-3 commits**. The two GPUs split the work by split type -- GPU 0 takes
# `random` and `cold_drug`, GPU 1 `cold_target` and `cold_pair` -- for all three models, so
# both carry a similar load.

# %% [markdown]
# ## 1. Check the GPUs

# %%
import time
START = time.time()          # the 11-hour self-stop is measured from here

import torch

assert torch.cuda.is_available(), 'No CUDA. Settings -> Accelerator -> GPU T4 x2.'
N_GPU = torch.cuda.device_count()
for i in range(N_GPU):
    p = torch.cuda.get_device_properties(i)
    print(f'GPU {i}: {p.name}, {p.total_memory/1e9:.1f} GB')
print('torch  :', torch.__version__)

# Measured peak memory on a 1000-residue protein (STATUS.md):
#   ColdSite-DTI  batch 64 -> 8.7 GB, 16 -> 2.3 GB
#   HyperAttentionDTI  batch 32 -> ~5 GB; 8 x accum 4 is the same effective batch
#   DeepDTA  batch 256 -> 0.7 GB
big = torch.cuda.get_device_properties(0).total_memory / 1e9 >= 14
COLDSITE_BATCH = 64 if big else 16
HAT_BATCH, HAT_ACCUM = (32, 1) if big else (8, 4)
DEEPDTA_BATCH = 256
print(f'batches: ColdSite {COLDSITE_BATCH}, HAT {HAT_BATCH}x{HAT_ACCUM}, DeepDTA {DEEPDTA_BATCH}')
# Out:
# GPU 0: Tesla T4, 15.6 GB
# GPU 1: Tesla T4, 15.6 GB
# torch  : 2.10.0+cu128
# batches: ColdSite 64, HAT 32x1, DeepDTA 256

# %% [markdown]
# ## 2. Clone the repo
#
# Pinned to `main` on the fork. The cell refuses to continue on a checkout older than the
# binary-label fix: before it, ColdSite-DTI's binary run crashed at its first AUROC because
# the loader handed the model raw pKd values instead of classes.

# %%
import os

REPO = 'https://github.com/Mahim56207/ColdSite-DTI_New.git'
WORK = '/kaggle/working'
SRC  = f'{WORK}/ColdSite-DTI_New'

if not os.path.exists(SRC):
    # !git clone --branch main {REPO} {SRC}
os.chdir(SRC)
# !git pull origin main
# !pip install -q tabulate subword-nmt

import importlib, src.model.dataset as _ds
importlib.reload(_ds)
assert hasattr(_ds, 'BINARY_THRESHOLD'), (
    'This checkout predates the binary-label fix -- ColdSite-DTI would crash. '
    'Re-run this cell so git pull fetches main.')

RESULTS = f'{WORK}/results'
os.makedirs(RESULTS, exist_ok=True)
print()
# !git log --oneline -1
print('results ->', RESULTS)
# Out:
# Cloning into '/kaggle/working/ColdSite-DTI_New'...
# remote: Enumerating objects: 1048, done.
# remote: Counting objects: 100% (302/302), done.
# remote: Compressing objects: 100% (214/214), done.
# remote: Total 1048 (delta 177), reused 195 (delta 88), pack-reused 746 (from 1)
# Receiving objects: 100% (1048/1048), 185.03 MiB | 27.99 MiB/s, done.
# Resolving deltas: 100% (549/549), done.
# From https://github.com/Mahim56207/ColdSite-DTI_New
#  * branch            main       -> FETCH_HEAD
# Already up to date.
#
# 26e577b (HEAD -> main, origin/main, origin/HEAD) KLIFS pocket ground truth, artefact controls, and a DAVIS sequence audit
# results -> /kaggle/working/results

# %% [markdown]
# ## 3. Fetch the DeepDTA source files

# %%
BASE = 'https://raw.githubusercontent.com/hkmztrk/DeepDTA/master/data'
for ds in ('davis', 'kiba'):
    os.makedirs(f'src/data/baselines/deepdta/data/{ds}', exist_ok=True)
    for fname in ('ligands_can.txt', 'proteins.txt', 'Y'):
        target = f'src/data/baselines/deepdta/data/{ds}/{fname}'
        if not os.path.exists(target):
            # !curl -sL {BASE}/{ds}/{fname} -o {target}
# !python -m src.data.load_data
# Out:
# davis: 30056 measured pairs, 68 unique drugs, 442 unique targets, Y range [5.000, 10.796]
# kiba: 118254 measured pairs, 2111 unique drugs, 229 unique targets, Y range [0.000, 17.200]

# %% [markdown]
# Expected, exactly: `davis: 30056 measured pairs, 68 unique drugs, 442 unique targets,
# Y range [5.000, 10.796]`.

# %% [markdown]
# ## 4. Build the splits — and verify they match
#
# These 36 cells must come from the same splits as every other result in the project. The
# counts below were verified on a MacBook, on Colab and on Kaggle; the cell asserts them.

# %%
# !python -m src.data.build_splits 2>&1 | grep -E 'davis|leakage'

import pandas as pd

EXPECTED = {
    'random':      (21039, 3006, 6011),
    'cold_drug':   (21658, 2652, 5746),
    'cold_target': (21080, 2992, 5984),
    'cold_pair':   (15190,  264, 1144),
}
problems = []
for split, expected in EXPECTED.items():
    got = tuple(len(pd.read_csv(f'data/splits/davis/{split}/{part}.csv'))
                for part in ('train', 'valid', 'test'))
    if got != expected:
        problems.append(f'{split}: expected {expected}, got {got}')
    print(f"{split:12s} {str(got):26s} {'OK' if got == expected else 'MISMATCH'}")
assert not problems, 'Splits differ from the rest of the project:\n  ' + '\n  '.join(problems)
print('\nSplits match. Safe to train.')
# Out:
# === Building splits for davis ===
# Saved data/splits/davis/random/  train=21039  valid=3006  test=6011
# Saved data/splits/davis/cold_drug/  train=21658  valid=2652  test=5746
# Saved data/splits/davis/cold_target/  train=21080  valid=2992  test=5984
# Saved data/splits/davis/cold_pair/  train=15190  valid=264  test=1144
# cold_drug: no leakage across train/valid/test -- OK
# cold_target: no leakage across train/valid/test -- OK
# cold_pair: no leakage across train/valid/test -- OK
# cold_drug: no leakage across train/valid/test -- OK
# cold_target: no leakage across train/valid/test -- OK
# cold_pair: no leakage across train/valid/test -- OK
# random       (21039, 3006, 6011)        OK
# cold_drug    (21658, 2652, 5746)        OK
# cold_target  (21080, 2992, 5984)        OK
# cold_pair    (15190, 264, 1144)         OK
#
# Splits match. Safe to train.

# %% [markdown]
# ## 5. Restore results from the previous commit
#
# `None` on the first commit. After that, attach the dataset holding the previous output and
# put its path here. Only model files are copied, and nothing already present is overwritten.

# %%
import shutil, glob

# e.g. '/kaggle/input/coldsite-grid36-results'
RESTORE_FROM = '/kaggle/input'
if RESTORE_FROM:
    assert os.path.isdir(RESTORE_FROM), f'not a directory: {RESTORE_FROM}'
    copied = skipped = 0
    for src in glob.glob(f'{RESTORE_FROM}/**/*', recursive=True):
        name = os.path.basename(src)
        if not name.endswith(('.pt', '_results.json', '_history.json')):
            continue
        dst = os.path.join(RESULTS, name)
        if os.path.exists(dst):
            skipped += 1
            continue
        shutil.copy2(src, dst)
        copied += 1
    print(f'restored {copied} file(s), left {skipped} already present')
else:
    print('RESTORE_FROM is None -- starting from an empty results folder.')
# Out:
# restored 79 file(s), left 0 already present

# %% [markdown]
# ## 6. The runner
#
# Each GPU works through its own queue of commands in order; the two GPUs run in parallel.
# Output streams live, tagged `[GPU0]` / `[GPU1]`, and is teed to log files. At the 11-hour
# mark it stops launching new work and ends anything still running, so the commit can save.

# %%
import subprocess, threading

DEADLINE = START + 11 * 3600
SPLITS = ['random', 'cold_drug', 'cold_target', 'cold_pair']
SEEDS = [1,2,3]
SHARE = ({'0': ['random', 'cold_drug'], '1': ['cold_target', 'cold_pair']}
         if N_GPU >= 2 else {'0': SPLITS})


def hours_left():
    return (DEADLINE - time.time()) / 3600


def run_parallel(queues, label):
    """queues: {gpu: [command, ...]}. Returns True if the deadline cut it short."""
    current, state = {}, {'deadline': False}

    def worker(gpu, commands):
        env = {**os.environ, 'CUDA_VISIBLE_DEVICES': gpu, 'PYTHONUNBUFFERED': '1'}
        with open(f'{WORK}/{label}_gpu{gpu}.log', 'a') as log:
            for cmd in commands:
                if time.time() > DEADLINE:
                    return
                proc = subprocess.Popen(cmd, env=env, stdout=subprocess.PIPE,
                                        stderr=subprocess.STDOUT, text=True, bufsize=1)
                current[gpu] = proc
                for line in proc.stdout:
                    print(f'[GPU{gpu}] {line}', end='', flush=True)
                    log.write(line)
                    log.flush()
                code = proc.wait()
                if code != 0 and not state['deadline']:
                    print(f'[GPU{gpu}] !! exited {code}: {" ".join(cmd[3:])}', flush=True)

    threads = [threading.Thread(target=worker, args=(g, q), daemon=True)
               for g, q in queues.items()]
    for t in threads:
        t.start()
    while any(t.is_alive() for t in threads):
        if time.time() > DEADLINE and not state['deadline']:
            state['deadline'] = True
            print('\n*** 11-hour mark: stopping so this commit can save its output. '
                  'Unfinished cells are retrained next commit. ***\n', flush=True)
            for proc in list(current.values()):
                if proc.poll() is None:
                    proc.terminate()
        time.sleep(15)
    return state['deadline']


def deepdta_cmd(split, seed):
    return ['python', '-u', '-m', 'src.model.train_deepdta',
            '--split-dir', f'data/splits/davis/{split}', '--dataset', 'davis',
            '--split', split, '--task', 'binary', '--seed', str(seed),
            '--batch-size', str(DEEPDTA_BATCH), '--min-epochs', '10', '--epochs', '100',
            '--checkpoint-dir', RESULTS, '--results-dir', RESULTS, '--skip-if-done']


def coldsite_cmd(splits):
    return ['python', '-u', '-m', 'src.model.run_grid', '--datasets', 'davis',
            '--splits', ','.join(splits), '--seeds', ','.join(map(str, SEEDS)),
            '--task', 'binary', '--epochs', '100', '--min-epochs', '10',
            '--batch-size', str(COLDSITE_BATCH), '--results-dir', RESULTS]


def hat_cmd(split, seed):
    return ['python', '-u', '-m', 'src.model.train_hyperattentiondti',
            '--split-dir', f'data/splits/davis/{split}', '--dataset', 'davis',
            '--split', split, '--seed', str(seed),
            '--batch-size', str(HAT_BATCH), '--accum-steps', str(HAT_ACCUM),
            '--min-epochs', '10', '--epochs', '100',
            '--checkpoint-dir', RESULTS, '--results-dir', RESULTS, '--skip-if-done']


for gpu, splits in SHARE.items():
    print(f'GPU {gpu} -> {", ".join(splits)}  (all three models)')
print(f'{hours_left():.1f} h left before the self-stop')
# Out:
# GPU 0 -> random, cold_drug  (all three models)
# GPU 1 -> cold_target, cold_pair  (all three models)
# 11.0 h left before the self-stop

# %% [markdown]
# ## 7. Stage 1 — DeepDTA
#
# The cheapest model runs first, so a broken pipeline shows up in under an hour instead of
# after twenty. Cells already finished (restored) are skipped in seconds.

# %%
stage1 = {gpu: [deepdta_cmd(split, seed) for split in splits for seed in SEEDS]
          for gpu, splits in SHARE.items()}
cut_short = run_parallel(stage1, 'deepdta')
print('\nDeepDTA stage', 'CUT SHORT by the deadline' if cut_short else 'done')
# Out:
# [GPU0] already done, skipping -> /kaggle/working/results/davis_random_binary_seed1_deepdta_results.json
# [GPU1] already done, skipping -> /kaggle/working/results/davis_cold_target_binary_seed1_deepdta_results.json
# [GPU0] already done, skipping -> /kaggle/working/results/davis_random_binary_seed2_deepdta_results.json
# [GPU1] already done, skipping -> /kaggle/working/results/davis_cold_target_binary_seed2_deepdta_results.json
# [GPU0] already done, skipping -> /kaggle/working/results/davis_random_binary_seed3_deepdta_results.json
# [GPU1] already done, skipping -> /kaggle/working/results/davis_cold_target_binary_seed3_deepdta_results.json
# [GPU0] already done, skipping -> /kaggle/working/results/davis_cold_drug_binary_seed1_deepdta_results.json
# [GPU1] already done, skipping -> /kaggle/working/results/davis_cold_pair_binary_seed1_deepdta_results.json
# [GPU0] already done, skipping -> /kaggle/working/results/davis_cold_drug_binary_seed2_deepdta_results.json
# [GPU1] already done, skipping -> /kaggle/working/results/davis_cold_pair_binary_seed2_deepdta_results.json
# [GPU0] already done, skipping -> /kaggle/working/results/davis_cold_drug_binary_seed3_deepdta_results.json
# [GPU1] already done, skipping -> /kaggle/working/results/davis_cold_pair_binary_seed3_deepdta_results.json
#
# DeepDTA stage done

# %% [markdown]
# ## 8. Sanity gate
#
# DAVIS `random` AUROC should be well above chance and below perfect -- roughly 0.85-0.92.
# **At 0.98 or above, something is leaking labels or the metric is wrong**, and spending
# twenty more hours on ColdSite-DTI and HyperAttentionDTI would only produce more wrong
# numbers. The gate does not raise (a failed commit may not save its output); it sets `GO`
# and stage 2 refuses to start.

# %%
import json, statistics as st
from src.model.checkpoint_naming import checkpoint_path, results_path, run_tag


def auroc(model, split, seed):
    path = results_path(RESULTS, run_tag('davis', split, 'binary', seed), model=model)
    if not os.path.exists(path):
        return None
    return json.load(open(path))['test_metrics'].get('auroc')


GO, reasons = True, []
for split in SPLITS:
    values = [a for a in (auroc('deepdta', split, s) for s in SEEDS) if a is not None]
    shown = f'{st.mean(values):.4f} over {len(values)} seed(s)' if values else 'no results'
    print(f'DeepDTA {split:12s} AUROC {shown}')

random_values = [a for a in (auroc('deepdta', 'random', s) for s in SEEDS) if a is not None]
if not random_values:
    GO = False; reasons.append('no DeepDTA random-split result to check against')
elif st.mean(random_values) >= 0.98:
    GO = False; reasons.append(f'random AUROC {st.mean(random_values):.4f} is implausibly '
                               'high -- suspect label leakage or a metric bug')
elif st.mean(random_values) < 0.60:
    GO = False; reasons.append(f'random AUROC {st.mean(random_values):.4f} is near chance '
                               '-- the pipeline is not learning')

if GO:
    print('\nGate passed. Stage 2 will run.')
else:
    print('\n' + '!' * 70 + '\nGATE FAILED -- stage 2 will NOT run:\n  - '
          + '\n  - '.join(reasons) + '\n' + '!' * 70)
# Out:
# DeepDTA random       AUROC 0.9290 over 3 seed(s)
# DeepDTA cold_drug    AUROC 0.6915 over 3 seed(s)
# DeepDTA cold_target  AUROC 0.9075 over 3 seed(s)
# DeepDTA cold_pair    AUROC 0.7277 over 3 seed(s)
#
# Gate passed. Stage 2 will run.

# %% [markdown]
# ## 9. Stage 2 — ColdSite-DTI, then HyperAttentionDTI
#
# The long stage. Each GPU trains ColdSite-DTI on its two split types, then
# HyperAttentionDTI on the same two. `run_grid` validates its first unfinished cell end to end
# before launching the rest.

# %%
if not GO:
    print('Skipped: the sanity gate failed. See section 8.')
elif hours_left() < 0.5:
    print(f'Skipped: only {hours_left():.1f} h left. Commit again with the restore cell set.')
else:
    stage2 = {gpu: [coldsite_cmd(splits)] + [hat_cmd(split, seed)
                                             for split in splits for seed in SEEDS]
              for gpu, splits in SHARE.items()}
    cut_short = run_parallel(stage2, 'stage2')
    print('\nStage 2', 'CUT SHORT by the deadline -- commit again' if cut_short else 'done')
# Out:
# [GPU0] Grid: 6 cells, 6 unique run tags
# [GPU0] warning: checkpoint already exists; the cell will be skipped if it is complete, retrained if it was interrupted: /kaggle/working/results/coldsite_dti_davis_random_binary_seed1.pt
# [GPU0] warning: checkpoint already exists; the cell will be skipped if it is complete, retrained if it was interrupted: /kaggle/working/results/coldsite_dti_davis_random_binary_seed2.pt
# [GPU0] warning: checkpoint already exists; the cell will be skipped if it is complete, retrained if it was interrupted: /kaggle/working/results/coldsite_dti_davis_random_binary_seed3.pt
# [GPU0] warning: checkpoint already exists; the cell will be skipped if it is complete, retrained if it was interrupted: /kaggle/working/results/coldsite_dti_davis_cold_drug_binary_seed1.pt
# [GPU0] warning: checkpoint already exists; the cell will be skipped if it is complete, retrained if it was interrupted: /kaggle/working/results/coldsite_dti_davis_cold_drug_binary_seed2.pt
# [GPU0] warning: checkpoint already exists; the cell will be skipped if it is complete, retrained if it was interrupted: /kaggle/working/results/coldsite_dti_davis_cold_drug_binary_seed3.pt
# [GPU0] warning: task is 'binary', not 'regression'
# [GPU0]
# [GPU0] ready_to_launch: True
# [GPU0]
# [GPU0] Every cell is already complete — nothing to validate.
# [GPU0] [skip] davis/random/seed1 — already complete
# [GPU0] [skip] davis/random/seed2 — already complete
# [GPU0] [skip] davis/random/seed3 — already complete
# [GPU0] [skip] davis/cold_drug/seed1 — already complete
# [GPU0] [skip] davis/cold_drug/seed2 — already complete
# [GPU0] [skip] davis/cold_drug/seed3 — already complete
# [GPU0]
# [GPU0] | dataset | split | seed | checkpoint | accuracy | status |
# [GPU0] |---|---|---|---|---|---|
# [GPU0] | davis | random | 1 | `coldsite_dti_davis_random_binary_seed1.pt` | 0.9254 | ok |
# [GPU0] | davis | random | 2 | `coldsite_dti_davis_random_binary_seed2.pt` | 0.9232 | ok |
# [GPU0] | davis | random | 3 | `coldsite_dti_davis_random_binary_seed3.pt` | 0.9234 | ok |
# [GPU0] | davis | cold_drug | 1 | `coldsite_dti_davis_cold_drug_binary_seed1.pt` | 0.7233 | ok |
# [GPU0] | davis | cold_drug | 2 | `coldsite_dti_davis_cold_drug_binary_seed2.pt` | 0.7121 | ok |
# [GPU0] | davis | cold_drug | 3 | `coldsite_dti_davis_cold_drug_binary_seed3.pt` | 0.7265 | ok |
# [GPU0] | davis | cold_target | 1 | `coldsite_dti_davis_cold_target_binary_seed1.pt` | 0.8501 | ok |
# [GPU0] | davis | cold_target | 2 | `coldsite_dti_davis_cold_target_binary_seed2.pt` | 0.8513 | ok |
# [GPU0] | davis | cold_target | 3 | `coldsite_dti_davis_cold_target_binary_seed3.pt` | 0.8696 | ok |
# [GPU0] | davis | cold_pair | 1 | `coldsite_dti_davis_cold_pair_binary_seed1.pt` | 0.7375 | ok |
# [GPU0] | davis | cold_pair | 2 | `coldsite_dti_davis_cold_pair_binary_seed2.pt` | 0.5568 | ok |
# [GPU0] | davis | cold_pair | 3 | `coldsite_dti_davis_cold_pair_binary_seed3.pt` | 0.5765 | ok |
# [GPU0]
# [GPU0] 12 of 12 cells complete (accuracy = the task's headline metric on the test split; concordance index for regression, AUROC for binary).
# [GPU0]
# [GPU0] Saved -> /kaggle/working/results/grid_status.json
# [GPU0] Saved -> /kaggle/working/results/grid_status.md
# [GPU1] Grid: 6 cells, 6 unique run tags
# [GPU1] warning: checkpoint already exists; the cell will be skipped if it is complete, retrained if it was interrupted: /kaggle/working/results/coldsite_dti_davis_cold_target_binary_seed1.pt
# [GPU1] warning: checkpoint already exists; the cell will be skipped if it is complete, retrained if it was interrupted: /kaggle/working/results/coldsite_dti_davis_cold_target_binary_seed2.pt
# [GPU1] warning: checkpoint already exists; the cell will be skipped if it is complete, retrained if it was interrupted: /kaggle/working/results/coldsite_dti_davis_cold_target_binary_seed3.pt
# [GPU1] warning: checkpoint already exists; the cell will be skipped if it is complete, retrained if it was interrupted: /kaggle/working/results/coldsite_dti_davis_cold_pair_binary_seed1.pt
# [GPU1] warning: checkpoint already exists; the cell will be skipped if it is complete, retrained if it was interrupted: /kaggle/working/results/coldsite_dti_davis_cold_pair_binary_seed2.pt
# [GPU1] warning: checkpoint already exists; the cell will be skipped if it is complete, retrained if it was interrupted: /kaggle/working/results/coldsite_dti_davis_cold_pair_binary_seed3.pt
# [GPU1] warning: task is 'binary', not 'regression'
# [GPU1]
# [GPU1] ready_to_launch: True
# [GPU1]
# [GPU1] Every cell is already complete — nothing to validate.
# [GPU1] [skip] davis/cold_target/seed1 — already complete
# [GPU1] [skip] davis/cold_target/seed2 — already complete
# [GPU1] [skip] davis/cold_target/seed3 — already complete
# [GPU1] [skip] davis/cold_pair/seed1 — already complete
# [GPU1] [skip] davis/cold_pair/seed2 — already complete
# [GPU1] [skip] davis/cold_pair/seed3 — already complete
# [GPU1]
# [GPU1] | dataset | split | seed | checkpoint | accuracy | status |
# [GPU1] |---|---|---|---|---|---|
# [GPU1] | davis | random | 1 | `coldsite_dti_davis_random_binary_seed1.pt` | 0.9254 | ok |
# [GPU1] | davis | random | 2 | `coldsite_dti_davis_random_binary_seed2.pt` | 0.9232 | ok |
# [GPU1] | davis | random | 3 | `coldsite_dti_davis_random_binary_seed3.pt` | 0.9234 | ok |
# [GPU1] | davis | cold_drug | 1 | `coldsite_dti_davis_cold_drug_binary_seed1.pt` | 0.7233 | ok |
# [GPU1] | davis | cold_drug | 2 | `coldsite_dti_davis_cold_drug_binary_seed2.pt` | 0.7121 | ok |
# [GPU1] | davis | cold_drug | 3 | `coldsite_dti_davis_cold_drug_binary_seed3.pt` | 0.7265 | ok |
# [GPU1] | davis | cold_target | 1 | `coldsite_dti_davis_cold_target_binary_seed1.pt` | 0.8501 | ok |
# [GPU1] | davis | cold_target | 2 | `coldsite_dti_davis_cold_target_binary_seed2.pt` | 0.8513 | ok |
# [GPU1] | davis | cold_target | 3 | `coldsite_dti_davis_cold_target_binary_seed3.pt` | 0.8696 | ok |
# [GPU1] | davis | cold_pair | 1 | `coldsite_dti_davis_cold_pair_binary_seed1.pt` | 0.7375 | ok |
# [GPU1] | davis | cold_pair | 2 | `coldsite_dti_davis_cold_pair_binary_seed2.pt` | 0.5568 | ok |
# [GPU1] | davis | cold_pair | 3 | `coldsite_dti_davis_cold_pair_binary_seed3.pt` | 0.5765 | ok |
# [GPU1]
# [GPU1] 12 of 12 cells complete (accuracy = the task's headline metric on the test split; concordance index for regression, AUROC for binary).
# [GPU1]
# [GPU1] Saved -> /kaggle/working/results/grid_status.json
# [GPU1] Saved -> /kaggle/working/results/grid_status.md
# [GPU0] already done, skipping -> /kaggle/working/results/davis_random_binary_seed1_hyperattentiondti_results.json
# [GPU1] already done, skipping -> /kaggle/working/results/davis_cold_target_binary_seed1_hyperattentiondti_results.json
# [GPU0] already done, skipping -> /kaggle/working/results/davis_random_binary_seed2_hyperattentiondti_results.json
# [GPU1] already done, skipping -> /kaggle/working/results/davis_cold_target_binary_seed2_hyperattentiondti_results.json
# [GPU0] already done, skipping -> /kaggle/working/results/davis_random_binary_seed3_hyperattentiondti_results.json
# [GPU1] already done, skipping -> /kaggle/working/results/davis_cold_target_binary_seed3_hyperattentiondti_results.json
# [GPU1] already done, skipping -> /kaggle/working/results/davis_cold_pair_binary_seed1_hyperattentiondti_results.json
# [GPU0]   train  21,658 pairs  9.4% positive  <- data/splits/davis/cold_drug/train.csv
# [GPU0]   valid   2,652 pairs  4.9% positive  <- data/splits/davis/cold_drug/valid.csv
# [GPU0]   test    5,746 pairs  6.0% positive  <- data/splits/davis/cold_drug/test.csv
# [GPU0]
# [GPU0]   device        cuda (Tesla T4, 14.6 GB)
# [GPU0]   micro-batch   32 x 1 accum = effective 32 (vendored: 32)
# [GPU0]   optimiser steps/epoch  676
# [GPU0]   interaction tensor  1.59 GB each, ~6.3 GB of activations per step
# [GPU1] already done, skipping -> /kaggle/working/results/davis_cold_pair_binary_seed2_hyperattentiondti_results.json
# [GPU1] already done, skipping -> /kaggle/working/results/davis_cold_pair_binary_seed3_hyperattentiondti_results.json
# [GPU0]
# [GPU0]     epoch 1 train batch 20/677 loss 0.5368
# [GPU0]     epoch 1 train batch 40/677 loss 0.4389
# [GPU0]     epoch 1 train batch 60/677 loss 0.4026
# [GPU0]     epoch 1 train batch 80/677 loss 0.3823
# [GPU0]     epoch 1 train batch 100/677 loss 0.3729
# [GPU0]     epoch 1 train batch 120/677 loss 0.3558
# [GPU0]     epoch 1 train batch 140/677 loss 0.3554
# [GPU0]     epoch 1 train batch 160/677 loss 0.3533
# [GPU0]     epoch 1 train batch 180/677 loss 0.3513
# [GPU0]     epoch 1 train batch 200/677 loss 0.3453
# [GPU0]     epoch 1 train batch 220/677 loss 0.3372
# [GPU0]     epoch 1 train batch 240/677 loss 0.3301
# [GPU0]     epoch 1 train batch 260/677 loss 0.3302
# [GPU0]     epoch 1 train batch 280/677 loss 0.3252
# [GPU0]     epoch 1 train batch 300/677 loss 0.3210
# [GPU0]     epoch 1 train batch 320/677 loss 0.3149
# [GPU0]     epoch 1 train batch 340/677 loss 0.3102
# [GPU0]     epoch 1 train batch 360/677 loss 0.3031
# [GPU0]     epoch 1 train batch 380/677 loss 0.3013
# [GPU0]     epoch 1 train batch 400/677 loss 0.2993
# [GPU0]     epoch 1 train batch 420/677 loss 0.2973
# [GPU0]     epoch 1 train batch 440/677 loss 0.2956
# [GPU0]     epoch 1 train batch 460/677 loss 0.2940
# [GPU0]     epoch 1 train batch 480/677 loss 0.2924
# [GPU0]     epoch 1 train batch 500/677 loss 0.2897
# [GPU0]     epoch 1 train batch 520/677 loss 0.2886
# [GPU0]     epoch 1 train batch 540/677 loss 0.2870
# [GPU0]     epoch 1 train batch 560/677 loss 0.2846
# [GPU0]     epoch 1 train batch 580/677 loss 0.2840
# [GPU0]     epoch 1 train batch 600/677 loss 0.2817
# [GPU0]     epoch 1 train batch 620/677 loss 0.2799
# [GPU0]     epoch 1 train batch 640/677 loss 0.2801
# [GPU0]     epoch 1 train batch 660/677 loss 0.2782
# [GPU0]     epoch 1 train batch 677/677 loss 0.2793
# [GPU0]
# [GPU0]     epoch 1 valid batch 20/83 loss 0.1645
# [GPU0]     epoch 1 valid batch 40/83 loss 0.1858
# [GPU0]     epoch 1 valid batch 60/83 loss 0.2179
# [GPU0]     epoch 1 valid batch 80/83 loss 0.1936
# [GPU0]     epoch 1 valid batch 83/83 loss 0.1902
# [GPU0]   epoch   1 train 0.2793 val 0.1902 auroc 0.6522 auprc 0.1328 accuracy 0.9510
# [GPU0]
# [GPU0]     epoch 2 train batch 20/677 loss 0.2287
# [GPU0]     epoch 2 train batch 40/677 loss 0.2364
# [GPU0]     epoch 2 train batch 60/677 loss 0.2409
# [GPU0]     epoch 2 train batch 80/677 loss 0.2416
# [GPU0]     epoch 2 train batch 100/677 loss 0.2490
# [GPU0]     epoch 2 train batch 120/677 loss 0.2438
# [GPU0]     epoch 2 train batch 140/677 loss 0.2353
# [GPU0]     epoch 2 train batch 160/677 loss 0.2373
# [GPU0]     epoch 2 train batch 180/677 loss 0.2415
# [GPU0]     epoch 2 train batch 200/677 loss 0.2411
# [GPU0]     epoch 2 train batch 220/677 loss 0.2389
# [GPU0]     epoch 2 train batch 240/677 loss 0.2373
# [GPU0]     epoch 2 train batch 260/677 loss 0.2390
# [GPU0]     epoch 2 train batch 280/677 loss 0.2397
# [GPU0]     epoch 2 train batch 300/677 loss 0.2421
# [GPU0]     epoch 2 train batch 320/677 loss 0.2425
# [GPU0]     epoch 2 train batch 340/677 loss 0.2431
# [GPU0]     epoch 2 train batch 360/677 loss 0.2394
# [GPU0]     epoch 2 train batch 380/677 loss 0.2385
# [GPU0]     epoch 2 train batch 400/677 loss 0.2373
# [GPU0]     epoch 2 train batch 420/677 loss 0.2364
# [GPU0]     epoch 2 train batch 440/677 loss 0.2363
# [GPU0]     epoch 2 train batch 460/677 loss 0.2362
# [GPU0]     epoch 2 train batch 480/677 loss 0.2345
# [GPU0]     epoch 2 train batch 500/677 loss 0.2333
# [GPU0]     epoch 2 train batch 520/677 loss 0.2325
# [GPU0]     epoch 2 train batch 540/677 loss 0.2318
# [GPU0]     epoch 2 train batch 560/677 loss 0.2305
# [GPU0]     epoch 2 train batch 580/677 loss 0.2301
# [GPU0]     epoch 2 train batch 600/677 loss 0.2296
# [GPU0]     epoch 2 train batch 620/677 loss 0.2281
# [GPU0]     epoch 2 train batch 640/677 loss 0.2275
# [GPU0]     epoch 2 train batch 660/677 loss 0.2278
# [GPU0]     epoch 2 train batch 677/677 loss 0.2269
# [GPU0]
# [GPU0]     epoch 2 valid batch 20/83 loss 0.1644
# [GPU0]     epoch 2 valid batch 40/83 loss 0.1936
# [GPU0]     epoch 2 valid batch 60/83 loss 0.2186
# [GPU0]     epoch 2 valid batch 80/83 loss 0.1976
# [GPU0]     epoch 2 valid batch 83/83 loss 0.1952
# [GPU0]   epoch   2 train 0.2269 val 0.1952 auroc 0.6683 auprc 0.1369 accuracy 0.9510
# [GPU0]
# [GPU0]     epoch 3 train batch 20/677 loss 0.2033
# [GPU0]     epoch 3 train batch 40/677 loss 0.1998
# [GPU0]     epoch 3 train batch 60/677 loss 0.2075
# [GPU0]     epoch 3 train batch 80/677 loss 0.2091
# [GPU0]     epoch 3 train batch 100/677 loss 0.2001
# [GPU0]     epoch 3 train batch 120/677 loss 0.2030
# [GPU0]     epoch 3 train batch 140/677 loss 0.2009
# [GPU0]     epoch 3 train batch 160/677 loss 0.2072
# [GPU0]     epoch 3 train batch 180/677 loss 0.2065
# [GPU0]     epoch 3 train batch 200/677 loss 0.2044
# [GPU0]     epoch 3 train batch 220/677 loss 0.2079
# [GPU0]     epoch 3 train batch 240/677 loss 0.2088
# [GPU0]     epoch 3 train batch 260/677 loss 0.2070
# [GPU0]     epoch 3 train batch 280/677 loss 0.2080
# [GPU0]     epoch 3 train batch 300/677 loss 0.2091
# [GPU0]     epoch 3 train batch 320/677 loss 0.2092
# [GPU0]     epoch 3 train batch 340/677 loss 0.2085
# [GPU0]     epoch 3 train batch 360/677 loss 0.2099
# [GPU0]     epoch 3 train batch 380/677 loss 0.2105
# [GPU0]     epoch 3 train batch 400/677 loss 0.2124
# [GPU0]     epoch 3 train batch 420/677 loss 0.2119
# [GPU0]     epoch 3 train batch 440/677 loss 0.2115
# [GPU0]     epoch 3 train batch 460/677 loss 0.2135
# [GPU0]     epoch 3 train batch 480/677 loss 0.2126
# [GPU0]     epoch 3 train batch 500/677 loss 0.2127
# [GPU0]     epoch 3 train batch 520/677 loss 0.2118
# [GPU0]     epoch 3 train batch 540/677 loss 0.2100
# [GPU0]     epoch 3 train batch 560/677 loss 0.2107
# [GPU0]     epoch 3 train batch 580/677 loss 0.2117
# [GPU0]     epoch 3 train batch 600/677 loss 0.2122
# [GPU0]     epoch 3 train batch 620/677 loss 0.2127
# [GPU0]     epoch 3 train batch 640/677 loss 0.2134
# [GPU0]     epoch 3 train batch 660/677 loss 0.2130
# [GPU0]     epoch 3 train batch 677/677 loss 0.2135
# [GPU0]
# [GPU0]     epoch 3 valid batch 20/83 loss 0.2314
# [GPU0]     epoch 3 valid batch 40/83 loss 0.2549
# [GPU0]     epoch 3 valid batch 60/83 loss 0.2652
# [GPU0]     epoch 3 valid batch 80/83 loss 0.2584
# [GPU0]     epoch 3 valid batch 83/83 loss 0.2598
# [GPU0]   epoch   3 train 0.2135 val 0.2598 auroc 0.6589 auprc 0.0986 accuracy 0.9317
# [GPU0]
# [GPU0]     epoch 4 train batch 20/677 loss 0.2334
# [GPU0]     epoch 4 train batch 40/677 loss 0.2179
# [GPU0]     epoch 4 train batch 60/677 loss 0.1964
# [GPU0]     epoch 4 train batch 80/677 loss 0.1974
# [GPU0]     epoch 4 train batch 100/677 loss 0.1988
# [GPU0]     epoch 4 train batch 120/677 loss 0.2049
# [GPU0]     epoch 4 train batch 140/677 loss 0.2038
# [GPU0]     epoch 4 train batch 160/677 loss 0.2040
# [GPU0]     epoch 4 train batch 180/677 loss 0.2095
# [GPU0]     epoch 4 train batch 200/677 loss 0.2118
# [GPU0]     epoch 4 train batch 220/677 loss 0.2117
# [GPU0]     epoch 4 train batch 240/677 loss 0.2142
# [GPU0]     epoch 4 train batch 260/677 loss 0.2134
# [GPU0]     epoch 4 train batch 280/677 loss 0.2122
# [GPU0]     epoch 4 train batch 300/677 loss 0.2128
# [GPU0]     epoch 4 train batch 320/677 loss 0.2115
# [GPU0]     epoch 4 train batch 340/677 loss 0.2110
# [GPU0]     epoch 4 train batch 360/677 loss 0.2092
# [GPU0]     epoch 4 train batch 380/677 loss 0.2094
# [GPU0]     epoch 4 train batch 400/677 loss 0.2079
# [GPU0]     epoch 4 train batch 420/677 loss 0.2055
# [GPU0]     epoch 4 train batch 440/677 loss 0.2041
# [GPU0]     epoch 4 train batch 460/677 loss 0.2031
# [GPU0]     epoch 4 train batch 480/677 loss 0.2028
# [GPU0]     epoch 4 train batch 500/677 loss 0.2028
# [GPU0]     epoch 4 train batch 520/677 loss 0.2021
# [GPU0]     epoch 4 train batch 540/677 loss 0.2011
# [GPU0]     epoch 4 train batch 560/677 loss 0.2012
# [GPU0]     epoch 4 train batch 580/677 loss 0.2004
# [GPU0]     epoch 4 train batch 600/677 loss 0.1998
# [GPU0]     epoch 4 train batch 620/677 loss 0.2000
# [GPU0]     epoch 4 train batch 640/677 loss 0.1989
# [GPU0]     epoch 4 train batch 660/677 loss 0.1983
# [GPU0]     epoch 4 train batch 677/677 loss 0.1978
# [GPU0]
# [GPU0]     epoch 4 valid batch 20/83 loss 0.1375
# [GPU0]     epoch 4 valid batch 40/83 loss 0.1884
# [GPU0]     epoch 4 valid batch 60/83 loss 0.2080
# [GPU0]     epoch 4 valid batch 80/83 loss 0.1998
# [GPU0]     epoch 4 valid batch 83/83 loss 0.2001
# [GPU0]   epoch   4 train 0.1978 val 0.2001 auroc 0.7005 auprc 0.2812 accuracy 0.9514
# [GPU0]
# [GPU0]     epoch 5 train batch 20/677 loss 0.1518
# [GPU0]     epoch 5 train batch 40/677 loss 0.1754
# [GPU0]     epoch 5 train batch 60/677 loss 0.1643
# [GPU0]     epoch 5 train batch 80/677 loss 0.1629
# [GPU0]     epoch 5 train batch 100/677 loss 0.1553
# [GPU0]     epoch 5 train batch 120/677 loss 0.1586
# [GPU0]     epoch 5 train batch 140/677 loss 0.1593
# [GPU0]     epoch 5 train batch 160/677 loss 0.1632
# [GPU0]     epoch 5 train batch 180/677 loss 0.1638
# [GPU0]     epoch 5 train batch 200/677 loss 0.1653
# [GPU0]     epoch 5 train batch 220/677 loss 0.1652
# [GPU0]     epoch 5 train batch 240/677 loss 0.1640
# [GPU0]     epoch 5 train batch 260/677 loss 0.1661
# [GPU0]     epoch 5 train batch 280/677 loss 0.1685
# [GPU0]     epoch 5 train batch 300/677 loss 0.1685
# [GPU0]     epoch 5 train batch 320/677 loss 0.1683
# [GPU0]     epoch 5 train batch 340/677 loss 0.1684
# [GPU0]     epoch 5 train batch 360/677 loss 0.1702
# [GPU0]     epoch 5 train batch 380/677 loss 0.1712
# [GPU0]     epoch 5 train batch 400/677 loss 0.1765
# [GPU0]     epoch 5 train batch 420/677 loss 0.1772
# [GPU0]     epoch 5 train batch 440/677 loss 0.1765
# [GPU0]     epoch 5 train batch 460/677 loss 0.1758
# [GPU0]     epoch 5 train batch 480/677 loss 0.1756
# [GPU0]     epoch 5 train batch 500/677 loss 0.1765
# [GPU0]     epoch 5 train batch 520/677 loss 0.1767
# [GPU0]     epoch 5 train batch 540/677 loss 0.1771
# [GPU0]     epoch 5 train batch 560/677 loss 0.1770
# [GPU0]     epoch 5 train batch 580/677 loss 0.1771
# [GPU0]     epoch 5 train batch 600/677 loss 0.1769
# [GPU0]     epoch 5 train batch 620/677 loss 0.1774
# [GPU0]     epoch 5 train batch 640/677 loss 0.1782
# [GPU0]     epoch 5 train batch 660/677 loss 0.1776
# [GPU0]     epoch 5 train batch 677/677 loss 0.1786
# [GPU0]
# [GPU0]     epoch 5 valid batch 20/83 loss 0.1440
# [GPU0]     epoch 5 valid batch 40/83 loss 0.1877
# [GPU0]     epoch 5 valid batch 60/83 loss 0.2289
# [GPU0]     epoch 5 valid batch 80/83 loss 0.2027
# [GPU0]     epoch 5 valid batch 83/83 loss 0.2007
# [GPU0]   epoch   5 train 0.1786 val 0.2007 auroc 0.6455 auprc 0.1269 accuracy 0.9502
# [GPU0]
# [GPU0]     epoch 6 train batch 20/677 loss 0.1559
# [GPU0]     epoch 6 train batch 40/677 loss 0.1654
# [GPU0]     epoch 6 train batch 60/677 loss 0.1657
# [GPU0]     epoch 6 train batch 80/677 loss 0.1647
# [GPU0]     epoch 6 train batch 100/677 loss 0.1608
# [GPU0]     epoch 6 train batch 120/677 loss 0.1607
# [GPU0]     epoch 6 train batch 140/677 loss 0.1598
# [GPU0]     epoch 6 train batch 160/677 loss 0.1658
# [GPU0]     epoch 6 train batch 180/677 loss 0.1658
# [GPU0]     epoch 6 train batch 200/677 loss 0.1687
# [GPU0]     epoch 6 train batch 220/677 loss 0.1745
# [GPU0]     epoch 6 train batch 240/677 loss 0.1754
# [GPU0]     epoch 6 train batch 260/677 loss 0.1762
# [GPU0]     epoch 6 train batch 280/677 loss 0.1770
# [GPU0]     epoch 6 train batch 300/677 loss 0.1781
# [GPU0]     epoch 6 train batch 320/677 loss 0.1772
# [GPU0]     epoch 6 train batch 340/677 loss 0.1774
# [GPU0]     epoch 6 train batch 360/677 loss 0.1760
# [GPU0]     epoch 6 train batch 380/677 loss 0.1759
# [GPU0]     epoch 6 train batch 400/677 loss 0.1761
# [GPU0]     epoch 6 train batch 420/677 loss 0.1777
# [GPU0]     epoch 6 train batch 440/677 loss 0.1787
# [GPU0]     epoch 6 train batch 460/677 loss 0.1793
# [GPU0]     epoch 6 train batch 480/677 loss 0.1788
# [GPU0]     epoch 6 train batch 500/677 loss 0.1790
# [GPU0]     epoch 6 train batch 520/677 loss 0.1779
# [GPU0]     epoch 6 train batch 540/677 loss 0.1764
# [GPU0]     epoch 6 train batch 560/677 loss 0.1753
# [GPU0]     epoch 6 train batch 580/677 loss 0.1744
# [GPU0]     epoch 6 train batch 600/677 loss 0.1744
# [GPU0]     epoch 6 train batch 620/677 loss 0.1736
# [GPU0]     epoch 6 train batch 640/677 loss 0.1732
# [GPU0]     epoch 6 train batch 660/677 loss 0.1730
# [GPU0]     epoch 6 train batch 677/677 loss 0.1724
# [GPU0]
# [GPU0]     epoch 6 valid batch 20/83 loss 0.1375
# [GPU0]     epoch 6 valid batch 40/83 loss 0.1890
# [GPU0]     epoch 6 valid batch 60/83 loss 0.2253
# [GPU0]     epoch 6 valid batch 80/83 loss 0.2131
# [GPU0]     epoch 6 valid batch 83/83 loss 0.2143
# [GPU0]   epoch   6 train 0.1724 val 0.2143 auroc 0.6699 auprc 0.1595 accuracy 0.9476
# [GPU0]
# [GPU0]     epoch 7 train batch 20/677 loss 0.1610
# [GPU0]     epoch 7 train batch 40/677 loss 0.1397
# [GPU0]     epoch 7 train batch 60/677 loss 0.1406
# [GPU0]     epoch 7 train batch 80/677 loss 0.1439
# [GPU0]     epoch 7 train batch 100/677 loss 0.1389
# [GPU0]     epoch 7 train batch 120/677 loss 0.1368
# [GPU0]     epoch 7 train batch 140/677 loss 0.1430
# [GPU0]     epoch 7 train batch 160/677 loss 0.1455
# [GPU0]     epoch 7 train batch 180/677 loss 0.1455
# [GPU0]     epoch 7 train batch 200/677 loss 0.1434
# [GPU0]     epoch 7 train batch 220/677 loss 0.1430
# [GPU0]     epoch 7 train batch 240/677 loss 0.1451
# [GPU0]     epoch 7 train batch 260/677 loss 0.1490
# [GPU0]     epoch 7 train batch 280/677 loss 0.1516
# [GPU0]     epoch 7 train batch 300/677 loss 0.1518
# [GPU0]     epoch 7 train batch 320/677 loss 0.1514
# [GPU0]     epoch 7 train batch 340/677 loss 0.1522
# [GPU0]     epoch 7 train batch 360/677 loss 0.1525
# [GPU0]     epoch 7 train batch 380/677 loss 0.1534
# [GPU0]     epoch 7 train batch 400/677 loss 0.1546
# [GPU0]     epoch 7 train batch 420/677 loss 0.1559
# [GPU0]     epoch 7 train batch 440/677 loss 0.1549
# [GPU0]     epoch 7 train batch 460/677 loss 0.1546
# [GPU0]     epoch 7 train batch 480/677 loss 0.1547
# [GPU0]     epoch 7 train batch 500/677 loss 0.1540
# [GPU0]     epoch 7 train batch 520/677 loss 0.1536
# [GPU0]     epoch 7 train batch 540/677 loss 0.1557
# [GPU0]     epoch 7 train batch 560/677 loss 0.1572
# [GPU0]     epoch 7 train batch 580/677 loss 0.1578
# [GPU0]     epoch 7 train batch 600/677 loss 0.1589
# [GPU0]     epoch 7 train batch 620/677 loss 0.1572
# [GPU0]     epoch 7 train batch 640/677 loss 0.1578
# [GPU0]     epoch 7 train batch 660/677 loss 0.1585
# [GPU0]     epoch 7 train batch 677/677 loss 0.1586
# [GPU0]
# [GPU0]     epoch 7 valid batch 20/83 loss 0.1400
# [GPU0]     epoch 7 valid batch 40/83 loss 0.1695
# [GPU0]     epoch 7 valid batch 60/83 loss 0.2189
# [GPU0]     epoch 7 valid batch 80/83 loss 0.1911
# [GPU0]     epoch 7 valid batch 83/83 loss 0.1886
# [GPU0]   epoch   7 train 0.1586 val 0.1886 auroc 0.6707 auprc 0.1328 accuracy 0.9510
# [GPU0]
# [GPU0]     epoch 8 train batch 20/677 loss 0.1694
# [GPU0]     epoch 8 train batch 40/677 loss 0.1655
# [GPU0]     epoch 8 train batch 60/677 loss 0.1574
# [GPU0]     epoch 8 train batch 80/677 loss 0.1583
# [GPU0]     epoch 8 train batch 100/677 loss 0.1610
# [GPU0]     epoch 8 train batch 120/677 loss 0.1613
# [GPU0]     epoch 8 train batch 140/677 loss 0.1632
# [GPU0]     epoch 8 train batch 160/677 loss 0.1626
# [GPU0]     epoch 8 train batch 180/677 loss 0.1629
# [GPU0]     epoch 8 train batch 200/677 loss 0.1634
# [GPU0]     epoch 8 train batch 220/677 loss 0.1624
# [GPU0]     epoch 8 train batch 240/677 loss 0.1645
# [GPU0]     epoch 8 train batch 260/677 loss 0.1665
# [GPU0]     epoch 8 train batch 280/677 loss 0.1672
# [GPU0]     epoch 8 train batch 300/677 loss 0.1637
# [GPU0]     epoch 8 train batch 320/677 loss 0.1629
# [GPU0]     epoch 8 train batch 340/677 loss 0.1623
# [GPU0]     epoch 8 train batch 360/677 loss 0.1624
# [GPU0]     epoch 8 train batch 380/677 loss 0.1626
# [GPU0]     epoch 8 train batch 400/677 loss 0.1635
# [GPU0]     epoch 8 train batch 420/677 loss 0.1630
# [GPU0]     epoch 8 train batch 440/677 loss 0.1633
# [GPU0]     epoch 8 train batch 460/677 loss 0.1634
# [GPU0]     epoch 8 train batch 480/677 loss 0.1614
# [GPU0]     epoch 8 train batch 500/677 loss 0.1607
# [GPU0]     epoch 8 train batch 520/677 loss 0.1610
# [GPU0]     epoch 8 train batch 540/677 loss 0.1601
# [GPU0]     epoch 8 train batch 560/677 loss 0.1601
# [GPU0]     epoch 8 train batch 580/677 loss 0.1589
# [GPU0]     epoch 8 train batch 600/677 loss 0.1596
# [GPU0]     epoch 8 train batch 620/677 loss 0.1590
# [GPU0]     epoch 8 train batch 640/677 loss 0.1579
# [GPU0]     epoch 8 train batch 660/677 loss 0.1580
# [GPU0]     epoch 8 train batch 677/677 loss 0.1576
# [GPU0]
# [GPU0]     epoch 8 valid batch 20/83 loss 0.1437
# [GPU0]     epoch 8 valid batch 40/83 loss 0.2157
# [GPU0]     epoch 8 valid batch 60/83 loss 0.2363
# [GPU0]     epoch 8 valid batch 80/83 loss 0.2204
# [GPU0]     epoch 8 valid batch 83/83 loss 0.2214
# [GPU0]   epoch   8 train 0.1576 val 0.2214 auroc 0.6964 auprc 0.1478 accuracy 0.9408
# [GPU0]
# [GPU0]     epoch 9 train batch 20/677 loss 0.1377
# [GPU0]     epoch 9 train batch 40/677 loss 0.1311
# [GPU0]     epoch 9 train batch 60/677 loss 0.1242
# [GPU0]     epoch 9 train batch 80/677 loss 0.1262
# [GPU0]     epoch 9 train batch 100/677 loss 0.1283
# [GPU0]     epoch 9 train batch 120/677 loss 0.1272
# [GPU0]     epoch 9 train batch 140/677 loss 0.1315
# [GPU0]     epoch 9 train batch 160/677 loss 0.1324
# [GPU0]     epoch 9 train batch 180/677 loss 0.1337
# [GPU0]     epoch 9 train batch 200/677 loss 0.1356
# [GPU0]     epoch 9 train batch 220/677 loss 0.1336
# [GPU0]     epoch 9 train batch 240/677 loss 0.1318
# [GPU0]     epoch 9 train batch 260/677 loss 0.1316
# [GPU0]     epoch 9 train batch 280/677 loss 0.1320
# [GPU0]     epoch 9 train batch 300/677 loss 0.1325
# [GPU0]     epoch 9 train batch 320/677 loss 0.1332
# [GPU0]     epoch 9 train batch 340/677 loss 0.1338
# [GPU0]     epoch 9 train batch 360/677 loss 0.1348
# [GPU0]     epoch 9 train batch 380/677 loss 0.1375
# [GPU0]     epoch 9 train batch 400/677 loss 0.1375
# [GPU0]     epoch 9 train batch 420/677 loss 0.1374
# [GPU0]     epoch 9 train batch 440/677 loss 0.1387
# [GPU0]     epoch 9 train batch 460/677 loss 0.1409
# [GPU0]     epoch 9 train batch 480/677 loss 0.1407
# [GPU0]     epoch 9 train batch 500/677 loss 0.1403
# [GPU0]     epoch 9 train batch 520/677 loss 0.1431
# [GPU0]     epoch 9 train batch 540/677 loss 0.1437
# [GPU0]     epoch 9 train batch 560/677 loss 0.1441
# [GPU0]     epoch 9 train batch 580/677 loss 0.1445
# [GPU0]     epoch 9 train batch 600/677 loss 0.1436
# [GPU0]     epoch 9 train batch 620/677 loss 0.1430
# [GPU0]     epoch 9 train batch 640/677 loss 0.1434
# [GPU0]     epoch 9 train batch 660/677 loss 0.1442
# [GPU0]     epoch 9 train batch 677/677 loss 0.1442
# [GPU0]
# [GPU0]     epoch 9 valid batch 20/83 loss 0.1274
# [GPU0]     epoch 9 valid batch 40/83 loss 0.1890
# [GPU0]     epoch 9 valid batch 60/83 loss 0.2323
# [GPU0]     epoch 9 valid batch 80/83 loss 0.2104
# [GPU0]     epoch 9 valid batch 83/83 loss 0.2094
# [GPU0]   epoch   9 train 0.1442 val 0.2094 auroc 0.6576 auprc 0.1601 accuracy 0.9487
# [GPU0]
# [GPU0]     epoch 10 train batch 20/677 loss 0.1510
# [GPU0]     epoch 10 train batch 40/677 loss 0.1445
# [GPU0]     epoch 10 train batch 60/677 loss 0.1489
# [GPU0]     epoch 10 train batch 80/677 loss 0.1497
# [GPU0]     epoch 10 train batch 100/677 loss 0.1541
# [GPU0]     epoch 10 train batch 120/677 loss 0.1486
# [GPU0]     epoch 10 train batch 140/677 loss 0.1538
# [GPU0]     epoch 10 train batch 160/677 loss 0.1517
# [GPU0]     epoch 10 train batch 180/677 loss 0.1546
# [GPU0]     epoch 10 train batch 200/677 loss 0.1527
# [GPU0]     epoch 10 train batch 220/677 loss 0.1532
# [GPU0]     epoch 10 train batch 240/677 loss 0.1518
# [GPU0]     epoch 10 train batch 260/677 loss 0.1519
# [GPU0]     epoch 10 train batch 280/677 loss 0.1537
# [GPU0]     epoch 10 train batch 300/677 loss 0.1520
# [GPU0]     epoch 10 train batch 320/677 loss 0.1543
# [GPU0]     epoch 10 train batch 340/677 loss 0.1523
# [GPU0]     epoch 10 train batch 360/677 loss 0.1504
# [GPU0]     epoch 10 train batch 380/677 loss 0.1484
# [GPU0]     epoch 10 train batch 400/677 loss 0.1497
# [GPU0]     epoch 10 train batch 420/677 loss 0.1494
# [GPU0]     epoch 10 train batch 440/677 loss 0.1496
# [GPU0]     epoch 10 train batch 460/677 loss 0.1486
# [GPU0]     epoch 10 train batch 480/677 loss 0.1483
# [GPU0]     epoch 10 train batch 500/677 loss 0.1464
# [GPU0]     epoch 10 train batch 520/677 loss 0.1453
# [GPU0]     epoch 10 train batch 540/677 loss 0.1445
# [GPU0]     epoch 10 train batch 560/677 loss 0.1442
# [GPU0]     epoch 10 train batch 580/677 loss 0.1433
# [GPU0]     epoch 10 train batch 600/677 loss 0.1431
# [GPU0]     epoch 10 train batch 620/677 loss 0.1423
# [GPU0]     epoch 10 train batch 640/677 loss 0.1433
# [GPU0]     epoch 10 train batch 660/677 loss 0.1436
# [GPU0]     epoch 10 train batch 677/677 loss 0.1435
# [GPU0]
# [GPU0]     epoch 10 valid batch 20/83 loss 0.1442
# [GPU0]     epoch 10 valid batch 40/83 loss 0.2038
# [GPU0]     epoch 10 valid batch 60/83 loss 0.2256
# [GPU0]     epoch 10 valid batch 80/83 loss 0.2116
# [GPU0]     epoch 10 valid batch 83/83 loss 0.2131
# [GPU0]   epoch  10 train 0.1435 val 0.2131 auroc 0.7002 auprc 0.1624 accuracy 0.9480
# [GPU0]
# [GPU0]     epoch 11 train batch 20/677 loss 0.1274
# [GPU0]     epoch 11 train batch 40/677 loss 0.1102
# [GPU0]     epoch 11 train batch 60/677 loss 0.1196
# [GPU0]     epoch 11 train batch 80/677 loss 0.1242
# [GPU0]     epoch 11 train batch 100/677 loss 0.1242
# [GPU0]     epoch 11 train batch 120/677 loss 0.1239
# [GPU0]     epoch 11 train batch 140/677 loss 0.1240
# [GPU0]     epoch 11 train batch 160/677 loss 0.1204
# [GPU0]     epoch 11 train batch 180/677 loss 0.1229
# [GPU0]     epoch 11 train batch 200/677 loss 0.1203
# [GPU0]     epoch 11 train batch 220/677 loss 0.1230
# [GPU0]     epoch 11 train batch 240/677 loss 0.1229
# [GPU0]     epoch 11 train batch 260/677 loss 0.1233
# [GPU0]     epoch 11 train batch 280/677 loss 0.1223
# [GPU0]     epoch 11 train batch 300/677 loss 0.1214
# [GPU0]     epoch 11 train batch 320/677 loss 0.1236
# [GPU0]     epoch 11 train batch 340/677 loss 0.1225
# [GPU0]     epoch 11 train batch 360/677 loss 0.1223
# [GPU0]     epoch 11 train batch 380/677 loss 0.1233
# [GPU0]     epoch 11 train batch 400/677 loss 0.1235
# [GPU0]     epoch 11 train batch 420/677 loss 0.1251
# [GPU0]     epoch 11 train batch 440/677 loss 0.1260
# [GPU0]     epoch 11 train batch 460/677 loss 0.1265
# [GPU0]     epoch 11 train batch 480/677 loss 0.1267
# [GPU0]     epoch 11 train batch 500/677 loss 0.1271
# [GPU0]     epoch 11 train batch 520/677 loss 0.1281
# [GPU0]     epoch 11 train batch 540/677 loss 0.1284
# [GPU0]     epoch 11 train batch 560/677 loss 0.1285
# [GPU0]     epoch 11 train batch 580/677 loss 0.1286
# [GPU0]     epoch 11 train batch 600/677 loss 0.1287
# [GPU0]     epoch 11 train batch 620/677 loss 0.1302
# [GPU0]     epoch 11 train batch 640/677 loss 0.1311
# [GPU0]     epoch 11 train batch 660/677 loss 0.1312
# [GPU0]     epoch 11 train batch 677/677 loss 0.1311
# [GPU0]
# [GPU0]     epoch 11 valid batch 20/83 loss 0.1615
# [GPU0]     epoch 11 valid batch 40/83 loss 0.2243
# [GPU0]     epoch 11 valid batch 60/83 loss 0.2730
# [GPU0]     epoch 11 valid batch 80/83 loss 0.2477
# [GPU0]     epoch 11 valid batch 83/83 loss 0.2457
# [GPU0]   epoch  11 train 0.1311 val 0.2457 auroc 0.6019 auprc 0.1030 accuracy 0.9472
# [GPU0]
# [GPU0]     epoch 12 train batch 20/677 loss 0.1300
# [GPU0]     epoch 12 train batch 40/677 loss 0.1432
# [GPU0]     epoch 12 train batch 60/677 loss 0.1403
# [GPU0]     epoch 12 train batch 80/677 loss 0.1366
# [GPU0]     epoch 12 train batch 100/677 loss 0.1349
# [GPU0]     epoch 12 train batch 120/677 loss 0.1349
# [GPU0]     epoch 12 train batch 140/677 loss 0.1386
# [GPU0]     epoch 12 train batch 160/677 loss 0.1380
# [GPU0]     epoch 12 train batch 180/677 loss 0.1402
# [GPU0]     epoch 12 train batch 200/677 loss 0.1371
# [GPU0]     epoch 12 train batch 220/677 loss 0.1368
# [GPU0]     epoch 12 train batch 240/677 loss 0.1346
# [GPU0]     epoch 12 train batch 260/677 loss 0.1384
# [GPU0]     epoch 12 train batch 280/677 loss 0.1394
# [GPU0]     epoch 12 train batch 300/677 loss 0.1396
# [GPU0]     epoch 12 train batch 320/677 loss 0.1393
# [GPU0]     epoch 12 train batch 340/677 loss 0.1397
# [GPU0]     epoch 12 train batch 360/677 loss 0.1376
# [GPU0]     epoch 12 train batch 380/677 loss 0.1365
# [GPU0]     epoch 12 train batch 400/677 loss 0.1360
# [GPU0]     epoch 12 train batch 420/677 loss 0.1355
# [GPU0]     epoch 12 train batch 440/677 loss 0.1352
# [GPU0]     epoch 12 train batch 460/677 loss 0.1344
# [GPU0]     epoch 12 train batch 480/677 loss 0.1332
# [GPU0]     epoch 12 train batch 500/677 loss 0.1331
# [GPU0]     epoch 12 train batch 520/677 loss 0.1333
# [GPU0]     epoch 12 train batch 540/677 loss 0.1325
# [GPU0]     epoch 12 train batch 560/677 loss 0.1317
# [GPU0]     epoch 12 train batch 580/677 loss 0.1305
# [GPU0]     epoch 12 train batch 600/677 loss 0.1301
# [GPU0]     epoch 12 train batch 620/677 loss 0.1292
# [GPU0]     epoch 12 train batch 640/677 loss 0.1294
# [GPU0]     epoch 12 train batch 660/677 loss 0.1286
# [GPU0]     epoch 12 train batch 677/677 loss 0.1291
# [GPU0]
# [GPU0]     epoch 12 valid batch 20/83 loss 0.1575
# [GPU0]     epoch 12 valid batch 40/83 loss 0.2511
# [GPU0]     epoch 12 valid batch 60/83 loss 0.2697
# [GPU0]     epoch 12 valid batch 80/83 loss 0.2562
# [GPU0]     epoch 12 valid batch 83/83 loss 0.2582
# [GPU0]   epoch  12 train 0.1291 val 0.2582 auroc 0.6892 auprc 0.1471 accuracy 0.9186
# [GPU0]
# [GPU0]     epoch 13 train batch 20/677 loss 0.0729
# [GPU0]     epoch 13 train batch 40/677 loss 0.0833
# [GPU0]     epoch 13 train batch 60/677 loss 0.0913
# [GPU0]     epoch 13 train batch 80/677 loss 0.0903
# [GPU0]     epoch 13 train batch 100/677 loss 0.0921
# [GPU0]     epoch 13 train batch 120/677 loss 0.0951
# [GPU0]     epoch 13 train batch 140/677 loss 0.0963
# [GPU0]     epoch 13 train batch 160/677 loss 0.0953
# [GPU0]     epoch 13 train batch 180/677 loss 0.0950
# [GPU0]     epoch 13 train batch 200/677 loss 0.0942
# [GPU0]     epoch 13 train batch 220/677 loss 0.0938
# [GPU0]     epoch 13 train batch 240/677 loss 0.0948
# [GPU0]     epoch 13 train batch 260/677 loss 0.0963
# [GPU0]     epoch 13 train batch 280/677 loss 0.0982
# [GPU0]     epoch 13 train batch 300/677 loss 0.0985
# [GPU0]     epoch 13 train batch 320/677 loss 0.1010
# [GPU0]     epoch 13 train batch 340/677 loss 0.1025
# [GPU0]     epoch 13 train batch 360/677 loss 0.1028
# [GPU0]     epoch 13 train batch 380/677 loss 0.1036
# [GPU0]     epoch 13 train batch 400/677 loss 0.1044
# [GPU0]     epoch 13 train batch 420/677 loss 0.1049
# [GPU0]     epoch 13 train batch 440/677 loss 0.1069
# [GPU0]     epoch 13 train batch 460/677 loss 0.1071
# [GPU0]     epoch 13 train batch 480/677 loss 0.1080
# [GPU0]     epoch 13 train batch 500/677 loss 0.1097
# [GPU0]     epoch 13 train batch 520/677 loss 0.1105
# [GPU0]     epoch 13 train batch 540/677 loss 0.1113
# [GPU0]     epoch 13 train batch 560/677 loss 0.1124
# [GPU0]     epoch 13 train batch 580/677 loss 0.1122
# [GPU0]     epoch 13 train batch 600/677 loss 0.1126
# [GPU0]     epoch 13 train batch 620/677 loss 0.1130
# [GPU0]     epoch 13 train batch 640/677 loss 0.1151
# [GPU0]     epoch 13 train batch 660/677 loss 0.1158
# [GPU0]     epoch 13 train batch 677/677 loss 0.1170
# [GPU0]
# [GPU0]     epoch 13 valid batch 20/83 loss 0.2094
# [GPU0]     epoch 13 valid batch 40/83 loss 0.2643
# [GPU0]     epoch 13 valid batch 60/83 loss 0.2809
# [GPU0]     epoch 13 valid batch 80/83 loss 0.2626
# [GPU0]     epoch 13 valid batch 83/83 loss 0.2638
# [GPU0]   epoch  13 train 0.1170 val 0.2638 auroc 0.6393 auprc 0.0789 accuracy 0.9027
# [GPU0]
# [GPU0]     epoch 14 train batch 20/677 loss 0.1221
# [GPU0]     epoch 14 train batch 40/677 loss 0.1331
# [GPU0]     epoch 14 train batch 60/677 loss 0.1332
# [GPU0]     epoch 14 train batch 80/677 loss 0.1295
# [GPU0]     epoch 14 train batch 100/677 loss 0.1282
# [GPU0]     epoch 14 train batch 120/677 loss 0.1228
# [GPU0]     epoch 14 train batch 140/677 loss 0.1226
# [GPU0]     epoch 14 train batch 160/677 loss 0.1224
# [GPU0]     epoch 14 train batch 180/677 loss 0.1211
# [GPU0]     epoch 14 train batch 200/677 loss 0.1192
# [GPU0]     epoch 14 train batch 220/677 loss 0.1203
# [GPU0]     epoch 14 train batch 240/677 loss 0.1203
# [GPU0]     epoch 14 train batch 260/677 loss 0.1218
# [GPU0]     epoch 14 train batch 280/677 loss 0.1203
# [GPU0]     epoch 14 train batch 300/677 loss 0.1194
# [GPU0]     epoch 14 train batch 320/677 loss 0.1195
# [GPU0]     epoch 14 train batch 340/677 loss 0.1205
# [GPU0]     epoch 14 train batch 360/677 loss 0.1206
# [GPU0]     epoch 14 train batch 380/677 loss 0.1207
# [GPU0]     epoch 14 train batch 400/677 loss 0.1202
# [GPU0]     epoch 14 train batch 420/677 loss 0.1206
# [GPU0]     epoch 14 train batch 440/677 loss 0.1201
# [GPU0]     epoch 14 train batch 460/677 loss 0.1198
# [GPU0]     epoch 14 train batch 480/677 loss 0.1209
# [GPU0]     epoch 14 train batch 500/677 loss 0.1209
# [GPU0]     epoch 14 train batch 520/677 loss 0.1214
# [GPU0]     epoch 14 train batch 540/677 loss 0.1203
# [GPU0]     epoch 14 train batch 560/677 loss 0.1200
# [GPU0]     epoch 14 train batch 580/677 loss 0.1200
# [GPU0]     epoch 14 train batch 600/677 loss 0.1203
# [GPU0]     epoch 14 train batch 620/677 loss 0.1194
# [GPU0]     epoch 14 train batch 640/677 loss 0.1184
# [GPU0]     epoch 14 train batch 660/677 loss 0.1178
# [GPU0]     epoch 14 train batch 677/677 loss 0.1177
# [GPU0]
# [GPU0]     epoch 14 valid batch 20/83 loss 0.1454
# [GPU0]     epoch 14 valid batch 40/83 loss 0.2379
# [GPU0]     epoch 14 valid batch 60/83 loss 0.2906
# [GPU0]     epoch 14 valid batch 80/83 loss 0.2617
# [GPU0]     epoch 14 valid batch 83/83 loss 0.2639
# [GPU0]   epoch  14 train 0.1177 val 0.2639 auroc 0.6554 auprc 0.1040 accuracy 0.9351
# [GPU0]
# [GPU0]     epoch 15 train batch 20/677 loss 0.0836
# [GPU0]     epoch 15 train batch 40/677 loss 0.0854
# [GPU0]     epoch 15 train batch 60/677 loss 0.0794
# [GPU0]     epoch 15 train batch 80/677 loss 0.0811
# [GPU0]     epoch 15 train batch 100/677 loss 0.0795
# [GPU0]     epoch 15 train batch 120/677 loss 0.0797
# [GPU0]     epoch 15 train batch 140/677 loss 0.0796
# [GPU0]     epoch 15 train batch 160/677 loss 0.0822
# [GPU0]     epoch 15 train batch 180/677 loss 0.0820
# [GPU0]     epoch 15 train batch 200/677 loss 0.0821
# [GPU0]     epoch 15 train batch 220/677 loss 0.0827
# [GPU0]     epoch 15 train batch 240/677 loss 0.0842
# [GPU0]     epoch 15 train batch 260/677 loss 0.0861
# [GPU0]     epoch 15 train batch 280/677 loss 0.0867
# [GPU0]     epoch 15 train batch 300/677 loss 0.0872
# [GPU0]     epoch 15 train batch 320/677 loss 0.0892
# [GPU0]     epoch 15 train batch 340/677 loss 0.0914
# [GPU0]     epoch 15 train batch 360/677 loss 0.0923
# [GPU0]     epoch 15 train batch 380/677 loss 0.0929
# [GPU0]     epoch 15 train batch 400/677 loss 0.0943
# [GPU0]     epoch 15 train batch 420/677 loss 0.0940
# [GPU0]     epoch 15 train batch 440/677 loss 0.0933
# [GPU0]     epoch 15 train batch 460/677 loss 0.0938
# [GPU0]     epoch 15 train batch 480/677 loss 0.0944
# [GPU0]     epoch 15 train batch 500/677 loss 0.0952
# [GPU0]     epoch 15 train batch 520/677 loss 0.0960
# [GPU0]     epoch 15 train batch 540/677 loss 0.0960
# [GPU0]     epoch 15 train batch 560/677 loss 0.0973
# [GPU0]     epoch 15 train batch 580/677 loss 0.0978
# [GPU0]     epoch 15 train batch 600/677 loss 0.0982
# [GPU0]     epoch 15 train batch 620/677 loss 0.0987
# [GPU0]     epoch 15 train batch 640/677 loss 0.0991
# [GPU0]     epoch 15 train batch 660/677 loss 0.1004
# [GPU0]     epoch 15 train batch 677/677 loss 0.1007
# [GPU0]
# [GPU0]     epoch 15 valid batch 20/83 loss 0.1333
# [GPU0]     epoch 15 valid batch 40/83 loss 0.2272
# [GPU0]     epoch 15 valid batch 60/83 loss 0.2758
# [GPU0]     epoch 15 valid batch 80/83 loss 0.2387
# [GPU0]     epoch 15 valid batch 83/83 loss 0.2390
# [GPU0]   epoch  15 train 0.1007 val 0.2390 auroc 0.6375 auprc 0.1984 accuracy 0.9491
# [GPU0]
# [GPU0]     epoch 16 train batch 20/677 loss 0.1121
# [GPU0]     epoch 16 train batch 40/677 loss 0.1159
# [GPU0]     epoch 16 train batch 60/677 loss 0.1123
# [GPU0]     epoch 16 train batch 80/677 loss 0.1115
# [GPU0]     epoch 16 train batch 100/677 loss 0.1177
# [GPU0]     epoch 16 train batch 120/677 loss 0.1192
# [GPU0]     epoch 16 train batch 140/677 loss 0.1169
# [GPU0]     epoch 16 train batch 160/677 loss 0.1140
# [GPU0]     epoch 16 train batch 180/677 loss 0.1134
# [GPU0]     epoch 16 train batch 200/677 loss 0.1148
# [GPU0]     epoch 16 train batch 220/677 loss 0.1170
# [GPU0]     epoch 16 train batch 240/677 loss 0.1153
# [GPU0]     epoch 16 train batch 260/677 loss 0.1161
# [GPU0]     epoch 16 train batch 280/677 loss 0.1163
# [GPU0]     epoch 16 train batch 300/677 loss 0.1171
# [GPU0]     epoch 16 train batch 320/677 loss 0.1160
# [GPU0]     epoch 16 train batch 340/677 loss 0.1160
# [GPU0]     epoch 16 train batch 360/677 loss 0.1153
# [GPU0]     epoch 16 train batch 380/677 loss 0.1137
# [GPU0]     epoch 16 train batch 400/677 loss 0.1125
# [GPU0]     epoch 16 train batch 420/677 loss 0.1135
# [GPU0]     epoch 16 train batch 440/677 loss 0.1126
# [GPU0]     epoch 16 train batch 460/677 loss 0.1125
# [GPU0]     epoch 16 train batch 480/677 loss 0.1114
# [GPU0]     epoch 16 train batch 500/677 loss 0.1114
# [GPU0]     epoch 16 train batch 520/677 loss 0.1101
# [GPU0]     epoch 16 train batch 540/677 loss 0.1098
# [GPU0]     epoch 16 train batch 560/677 loss 0.1097
# [GPU0]     epoch 16 train batch 580/677 loss 0.1100
# [GPU0]     epoch 16 train batch 600/677 loss 0.1095
# [GPU0]     epoch 16 train batch 620/677 loss 0.1085
# [GPU0]     epoch 16 train batch 640/677 loss 0.1077
# [GPU0]     epoch 16 train batch 660/677 loss 0.1070
# [GPU0]     epoch 16 train batch 677/677 loss 0.1066
# [GPU0]
# [GPU0]     epoch 16 valid batch 20/83 loss 0.1740
# [GPU0]     epoch 16 valid batch 40/83 loss 0.2742
# [GPU0]     epoch 16 valid batch 60/83 loss 0.3128
# [GPU0]     epoch 16 valid batch 80/83 loss 0.2755
# [GPU0]     epoch 16 valid batch 83/83 loss 0.2778
# [GPU0]   epoch  16 train 0.1066 val 0.2778 auroc 0.6601 auprc 0.1383 accuracy 0.9246
# [GPU0]
# [GPU0]     epoch 17 train batch 20/677 loss 0.0742
# [GPU0]     epoch 17 train batch 40/677 loss 0.0663
# [GPU0]     epoch 17 train batch 60/677 loss 0.0670
# [GPU0]     epoch 17 train batch 80/677 loss 0.0709
# [GPU0]     epoch 17 train batch 100/677 loss 0.0728
# [GPU0]     epoch 17 train batch 120/677 loss 0.0738
# [GPU0]     epoch 17 train batch 140/677 loss 0.0744
# [GPU0]     epoch 17 train batch 160/677 loss 0.0752
# [GPU0]     epoch 17 train batch 180/677 loss 0.0757
# [GPU0]     epoch 17 train batch 200/677 loss 0.0737
# [GPU0]     epoch 17 train batch 220/677 loss 0.0756
# [GPU0]     epoch 17 train batch 240/677 loss 0.0766
# [GPU0]     epoch 17 train batch 260/677 loss 0.0764
# [GPU0]     epoch 17 train batch 280/677 loss 0.0771
# [GPU0]     epoch 17 train batch 300/677 loss 0.0768
# [GPU0]     epoch 17 train batch 320/677 loss 0.0764
# [GPU0]     epoch 17 train batch 340/677 loss 0.0779
# [GPU0]     epoch 17 train batch 360/677 loss 0.0787
# [GPU0]     epoch 17 train batch 380/677 loss 0.0782
# [GPU0]     epoch 17 train batch 400/677 loss 0.0792
# [GPU0]     epoch 17 train batch 420/677 loss 0.0797
# [GPU0]     epoch 17 train batch 440/677 loss 0.0812
# [GPU0]     epoch 17 train batch 460/677 loss 0.0825
# [GPU0]     epoch 17 train batch 480/677 loss 0.0838
# [GPU0]     epoch 17 train batch 500/677 loss 0.0853
# [GPU0]     epoch 17 train batch 520/677 loss 0.0859
# [GPU0]     epoch 17 train batch 540/677 loss 0.0865
# [GPU0]     epoch 17 train batch 560/677 loss 0.0872
# [GPU0]     epoch 17 train batch 580/677 loss 0.0873
# [GPU0]     epoch 17 train batch 600/677 loss 0.0887
# [GPU0]     epoch 17 train batch 620/677 loss 0.0898
# [GPU0]     epoch 17 train batch 640/677 loss 0.0906
# [GPU0]     epoch 17 train batch 660/677 loss 0.0912
# [GPU0]     epoch 17 train batch 677/677 loss 0.0929
# [GPU0]
# [GPU0]     epoch 17 valid batch 20/83 loss 0.1558
# [GPU0]     epoch 17 valid batch 40/83 loss 0.2128
# [GPU0]     epoch 17 valid batch 60/83 loss 0.2536
# [GPU0]     epoch 17 valid batch 80/83 loss 0.2291
# [GPU0]     epoch 17 valid batch 83/83 loss 0.2279
# [GPU0]   epoch  17 train 0.0929 val 0.2279 auroc 0.6439 auprc 0.1747 accuracy 0.9465
# [GPU0]
# [GPU0]     epoch 18 train batch 20/677 loss 0.1090
# [GPU0]     epoch 18 train batch 40/677 loss 0.1106
# [GPU0]     epoch 18 train batch 60/677 loss 0.1083
# [GPU0]     epoch 18 train batch 80/677 loss 0.1056
# [GPU0]     epoch 18 train batch 100/677 loss 0.1055
# [GPU0]     epoch 18 train batch 120/677 loss 0.1018
# [GPU0]     epoch 18 train batch 140/677 loss 0.1008
# [GPU0]     epoch 18 train batch 160/677 loss 0.1013
# [GPU0]     epoch 18 train batch 180/677 loss 0.1028
# [GPU0]     epoch 18 train batch 200/677 loss 0.1020
# [GPU0]     epoch 18 train batch 220/677 loss 0.1021
# [GPU0]     epoch 18 train batch 240/677 loss 0.1017
# [GPU0]     epoch 18 train batch 260/677 loss 0.1028
# [GPU0]     epoch 18 train batch 280/677 loss 0.1022
# [GPU0]     epoch 18 train batch 300/677 loss 0.1019
# [GPU0]     epoch 18 train batch 320/677 loss 0.1031
# [GPU0]     epoch 18 train batch 340/677 loss 0.1027
# [GPU0]     epoch 18 train batch 360/677 loss 0.1015
# [GPU0]     epoch 18 train batch 380/677 loss 0.1001
# [GPU0]     epoch 18 train batch 400/677 loss 0.0992
# [GPU0]     epoch 18 train batch 420/677 loss 0.0988
# [GPU0]     epoch 18 train batch 440/677 loss 0.0985
# [GPU0]     epoch 18 train batch 460/677 loss 0.0984
# [GPU0]     epoch 18 train batch 480/677 loss 0.0982
# [GPU0]     epoch 18 train batch 500/677 loss 0.0981
# [GPU0]     epoch 18 train batch 520/677 loss 0.0982
# [GPU0]     epoch 18 train batch 540/677 loss 0.0978
# [GPU0]     epoch 18 train batch 560/677 loss 0.0969
# [GPU0]     epoch 18 train batch 580/677 loss 0.0978
# [GPU0]     epoch 18 train batch 600/677 loss 0.0975
# [GPU0]     epoch 18 train batch 620/677 loss 0.0966
# [GPU0]     epoch 18 train batch 640/677 loss 0.0961
# [GPU0]     epoch 18 train batch 660/677 loss 0.0954
# [GPU0]     epoch 18 train batch 677/677 loss 0.0960
# [GPU0]
# [GPU0]     epoch 18 valid batch 20/83 loss 0.1817
# [GPU0]     epoch 18 valid batch 40/83 loss 0.2884
# [GPU0]     epoch 18 valid batch 60/83 loss 0.3248
# [GPU0]     epoch 18 valid batch 80/83 loss 0.2878
# [GPU0]     epoch 18 valid batch 83/83 loss 0.2863
# [GPU0]   epoch  18 train 0.0960 val 0.2863 auroc 0.6525 auprc 0.1762 accuracy 0.9201
# [GPU0]
# [GPU0]     epoch 19 train batch 20/677 loss 0.0606
# [GPU0]     epoch 19 train batch 40/677 loss 0.0586
# [GPU0]     epoch 19 train batch 60/677 loss 0.0595
# [GPU0]     epoch 19 train batch 80/677 loss 0.0616
# [GPU0]     epoch 19 train batch 100/677 loss 0.0653
# [GPU0]     epoch 19 train batch 120/677 loss 0.0653
# [GPU0]     epoch 19 train batch 140/677 loss 0.0633
# [GPU0]     epoch 19 train batch 160/677 loss 0.0640
# [GPU0]     epoch 19 train batch 180/677 loss 0.0642
# [GPU0]     epoch 19 train batch 200/677 loss 0.0641
# [GPU0]     epoch 19 train batch 220/677 loss 0.0647
# [GPU0]     epoch 19 train batch 240/677 loss 0.0648
# [GPU0]     epoch 19 train batch 260/677 loss 0.0669
# [GPU0]     epoch 19 train batch 280/677 loss 0.0678
# [GPU0]     epoch 19 train batch 300/677 loss 0.0672
# [GPU0]     epoch 19 train batch 320/677 loss 0.0690
# [GPU0]     epoch 19 train batch 340/677 loss 0.0707
# [GPU0]     epoch 19 train batch 360/677 loss 0.0717
# [GPU0]     epoch 19 train batch 380/677 loss 0.0721
# [GPU0]     epoch 19 train batch 400/677 loss 0.0720
# [GPU0]     epoch 19 train batch 420/677 loss 0.0738
# [GPU0]     epoch 19 train batch 440/677 loss 0.0738
# [GPU0]     epoch 19 train batch 460/677 loss 0.0749
# [GPU0]     epoch 19 train batch 480/677 loss 0.0752
# [GPU0]     epoch 19 train batch 500/677 loss 0.0764
# [GPU0]     epoch 19 train batch 520/677 loss 0.0775
# [GPU0]     epoch 19 train batch 540/677 loss 0.0785
# [GPU0]     epoch 19 train batch 560/677 loss 0.0801
# [GPU0]     epoch 19 train batch 580/677 loss 0.0811
# [GPU0]     epoch 19 train batch 600/677 loss 0.0823
# [GPU0]     epoch 19 train batch 620/677 loss 0.0831
# [GPU0]     epoch 19 train batch 640/677 loss 0.0841
# [GPU0]     epoch 19 train batch 660/677 loss 0.0842
# [GPU0]     epoch 19 train batch 677/677 loss 0.0841
# [GPU0]
# [GPU0]     epoch 19 valid batch 20/83 loss 0.1638
# [GPU0]     epoch 19 valid batch 40/83 loss 0.2510
# [GPU0]     epoch 19 valid batch 60/83 loss 0.3200
# [GPU0]     epoch 19 valid batch 80/83 loss 0.2761
# [GPU0]     epoch 19 valid batch 83/83 loss 0.2745
# [GPU0]   epoch  19 train 0.0841 val 0.2745 auroc 0.6238 auprc 0.1595 accuracy 0.9416
# [GPU0]
# [GPU0]     epoch 20 train batch 20/677 loss 0.0766
# [GPU0]     epoch 20 train batch 40/677 loss 0.0918
# [GPU0]     epoch 20 train batch 60/677 loss 0.0910
# [GPU0]     epoch 20 train batch 80/677 loss 0.0924
# ...
# [GPU0]     epoch 19 train batch 640/677 loss 0.0841
# [GPU0]     epoch 19 train batch 660/677 loss 0.0852
# [GPU0]     epoch 19 train batch 677/677 loss 0.0855
# [GPU0]
# [GPU0]     epoch 19 valid batch 20/83 loss 0.1792
# [GPU0]     epoch 19 valid batch 40/83 loss 0.2349
# [GPU0]     epoch 19 valid batch 60/83 loss 0.3311
# [GPU0]     epoch 19 valid batch 80/83 loss 0.3280
# [GPU0]     epoch 19 valid batch 83/83 loss 0.3262
# [GPU0]   epoch  19 train 0.0855 val 0.3262 auroc 0.5631 auprc 0.0751 accuracy 0.9099
# [GPU0]
# [GPU0]     epoch 20 train batch 20/677 loss 0.1035
# [GPU0]     epoch 20 train batch 40/677 loss 0.1078
# [GPU0]     epoch 20 train batch 60/677 loss 0.0997
# [GPU0]     epoch 20 train batch 80/677 loss 0.0993
# [GPU0]     epoch 20 train batch 100/677 loss 0.0986
# [GPU0]     epoch 20 train batch 120/677 loss 0.1031
# [GPU0]     epoch 20 train batch 140/677 loss 0.1044
# [GPU0]     epoch 20 train batch 160/677 loss 0.1036
# [GPU0]     epoch 20 train batch 180/677 loss 0.1013
# [GPU0]     epoch 20 train batch 200/677 loss 0.1029
# [GPU0]     epoch 20 train batch 220/677 loss 0.1020
# [GPU0]     epoch 20 train batch 240/677 loss 0.1002
# [GPU0]     epoch 20 train batch 260/677 loss 0.1001
# [GPU0]     epoch 20 train batch 280/677 loss 0.0997
# [GPU0]     epoch 20 train batch 300/677 loss 0.1012
# [GPU0]     epoch 20 train batch 320/677 loss 0.0998
# [GPU0]     epoch 20 train batch 340/677 loss 0.0990
# [GPU0]     epoch 20 train batch 360/677 loss 0.0974
# [GPU0]     epoch 20 train batch 380/677 loss 0.0978
# [GPU0]     epoch 20 train batch 400/677 loss 0.0987
# [GPU0]     epoch 20 train batch 420/677 loss 0.0975
# [GPU0]     epoch 20 train batch 440/677 loss 0.0960
# [GPU0]     epoch 20 train batch 460/677 loss 0.0947
# [GPU0]     epoch 20 train batch 480/677 loss 0.0939
# [GPU0]     epoch 20 train batch 500/677 loss 0.0934
# [GPU0]     epoch 20 train batch 520/677 loss 0.0931
# [GPU0]     epoch 20 train batch 540/677 loss 0.0928
# [GPU0]     epoch 20 train batch 560/677 loss 0.0924
# [GPU0]     epoch 20 train batch 580/677 loss 0.0918
# [GPU0]     epoch 20 train batch 600/677 loss 0.0909
# [GPU0]     epoch 20 train batch 620/677 loss 0.0906
# [GPU0]     epoch 20 train batch 640/677 loss 0.0905
# [GPU0]     epoch 20 train batch 660/677 loss 0.0905
# [GPU0]     epoch 20 train batch 677/677 loss 0.0906
# [GPU0]
# [GPU0]     epoch 20 valid batch 20/83 loss 0.1589
# [GPU0]     epoch 20 valid batch 40/83 loss 0.2117
# [GPU0]     epoch 20 valid batch 60/83 loss 0.3744
# [GPU0]     epoch 20 valid batch 80/83 loss 0.3589
# [GPU0]     epoch 20 valid batch 83/83 loss 0.3537
# [GPU0]   epoch  20 train 0.0906 val 0.3537 auroc 0.5196 auprc 0.0616 accuracy 0.9174
# [GPU0]
# [GPU0]     epoch 21 train batch 20/677 loss 0.0629
# [GPU0]     epoch 21 train batch 40/677 loss 0.0617
# [GPU0]     epoch 21 train batch 60/677 loss 0.0600
# [GPU0]     epoch 21 train batch 80/677 loss 0.0538
# [GPU0]     epoch 21 train batch 100/677 loss 0.0554
# [GPU0]     epoch 21 train batch 120/677 loss 0.0558
# [GPU0]     epoch 21 train batch 140/677 loss 0.0617
# [GPU0]     epoch 21 train batch 160/677 loss 0.0616
# [GPU0]     epoch 21 train batch 180/677 loss 0.0617
# [GPU0]     epoch 21 train batch 200/677 loss 0.0597
# [GPU0]     epoch 21 train batch 220/677 loss 0.0622
# [GPU0]     epoch 21 train batch 240/677 loss 0.0628
# [GPU0]     epoch 21 train batch 260/677 loss 0.0651
# [GPU0]     epoch 21 train batch 280/677 loss 0.0669
# [GPU0]     epoch 21 train batch 300/677 loss 0.0671
# [GPU0]     epoch 21 train batch 320/677 loss 0.0674
# [GPU0]     epoch 21 train batch 340/677 loss 0.0680
# [GPU0]     epoch 21 train batch 360/677 loss 0.0676
# [GPU0]     epoch 21 train batch 380/677 loss 0.0681
# [GPU0]     epoch 21 train batch 400/677 loss 0.0693
# [GPU0]     epoch 21 train batch 420/677 loss 0.0684
# [GPU0]     epoch 21 train batch 440/677 loss 0.0687
# [GPU0]     epoch 21 train batch 460/677 loss 0.0697
# [GPU0]     epoch 21 train batch 480/677 loss 0.0706
# [GPU0]     epoch 21 train batch 500/677 loss 0.0706
# [GPU0]     epoch 21 train batch 520/677 loss 0.0720
# [GPU0]     epoch 21 train batch 540/677 loss 0.0719
# [GPU0]     epoch 21 train batch 560/677 loss 0.0735
# [GPU0]     epoch 21 train batch 580/677 loss 0.0748
# [GPU0]     epoch 21 train batch 600/677 loss 0.0752
# [GPU0]     epoch 21 train batch 620/677 loss 0.0764
# [GPU0]     epoch 21 train batch 640/677 loss 0.0766
# [GPU0]     epoch 21 train batch 660/677 loss 0.0781
# [GPU0]     epoch 21 train batch 677/677 loss 0.0787
# [GPU0]
# [GPU0]     epoch 21 valid batch 20/83 loss 0.1833
# [GPU0]     epoch 21 valid batch 40/83 loss 0.2497
# [GPU0]     epoch 21 valid batch 60/83 loss 0.3075
# [GPU0]     epoch 21 valid batch 80/83 loss 0.2973
# [GPU0]     epoch 21 valid batch 83/83 loss 0.2945
# [GPU0]   epoch  21 train 0.0787 val 0.2945 auroc 0.5760 auprc 0.0755 accuracy 0.9118
# [GPU0]
# [GPU0]     epoch 22 train batch 20/677 loss 0.0834
# [GPU0]     epoch 22 train batch 40/677 loss 0.0796
# [GPU0]     epoch 22 train batch 60/677 loss 0.0879
# [GPU0]     epoch 22 train batch 80/677 loss 0.0869
# [GPU0]     epoch 22 train batch 100/677 loss 0.0907
# [GPU0]     epoch 22 train batch 120/677 loss 0.0935
# [GPU0]     epoch 22 train batch 140/677 loss 0.0929
# [GPU0]     epoch 22 train batch 160/677 loss 0.0922
# [GPU0]     epoch 22 train batch 180/677 loss 0.0913
# [GPU0]     epoch 22 train batch 200/677 loss 0.0928
# [GPU0]     epoch 22 train batch 220/677 loss 0.0922
# [GPU0]     epoch 22 train batch 240/677 loss 0.0924
# [GPU0]     epoch 22 train batch 260/677 loss 0.0933
# [GPU0]     epoch 22 train batch 280/677 loss 0.0935
# [GPU0]     epoch 22 train batch 300/677 loss 0.0915
# [GPU0]     epoch 22 train batch 320/677 loss 0.0901
# [GPU0]     epoch 22 train batch 340/677 loss 0.0892
# [GPU0]     epoch 22 train batch 360/677 loss 0.0887
# [GPU0]     epoch 22 train batch 380/677 loss 0.0899
# [GPU0]     epoch 22 train batch 400/677 loss 0.0888
# [GPU0]     epoch 22 train batch 420/677 loss 0.0885
# [GPU0]     epoch 22 train batch 440/677 loss 0.0881
# [GPU0]     epoch 22 train batch 460/677 loss 0.0878
# [GPU0]     epoch 22 train batch 480/677 loss 0.0881
# [GPU0]     epoch 22 train batch 500/677 loss 0.0874
# [GPU0]     epoch 22 train batch 520/677 loss 0.0866
# [GPU0]     epoch 22 train batch 540/677 loss 0.0860
# [GPU0]     epoch 22 train batch 560/677 loss 0.0853
# [GPU0]     epoch 22 train batch 580/677 loss 0.0852
# [GPU0]     epoch 22 train batch 600/677 loss 0.0845
# [GPU0]     epoch 22 train batch 620/677 loss 0.0836
# [GPU0]     epoch 22 train batch 640/677 loss 0.0836
# [GPU0]     epoch 22 train batch 660/677 loss 0.0829
# [GPU0]     epoch 22 train batch 677/677 loss 0.0823
# [GPU0]
# [GPU0]     epoch 22 valid batch 20/83 loss 0.1927
# [GPU0]     epoch 22 valid batch 40/83 loss 0.2328
# [GPU0]     epoch 22 valid batch 60/83 loss 0.3874
# [GPU0]     epoch 22 valid batch 80/83 loss 0.3589
# [GPU0]     epoch 22 valid batch 83/83 loss 0.3537
# [GPU0]   epoch  22 train 0.0823 val 0.3537 auroc 0.5380 auprc 0.0674 accuracy 0.9272
# [GPU0]
# [GPU0]     epoch 23 train batch 20/677 loss 0.0533
# [GPU0]     epoch 23 train batch 40/677 loss 0.0557
# [GPU0]     epoch 23 train batch 60/677 loss 0.0540
# [GPU0]     epoch 23 train batch 80/677 loss 0.0502
# [GPU0]     epoch 23 train batch 100/677 loss 0.0551
# [GPU0]     epoch 23 train batch 120/677 loss 0.0538
# [GPU0]     epoch 23 train batch 140/677 loss 0.0550
# [GPU0]     epoch 23 train batch 160/677 loss 0.0543
# [GPU0]     epoch 23 train batch 180/677 loss 0.0557
# [GPU0]     epoch 23 train batch 200/677 loss 0.0546
# [GPU0]     epoch 23 train batch 220/677 loss 0.0561
# [GPU0]     epoch 23 train batch 240/677 loss 0.0563
# [GPU0]     epoch 23 train batch 260/677 loss 0.0561
# [GPU0]     epoch 23 train batch 280/677 loss 0.0559
# [GPU0]     epoch 23 train batch 300/677 loss 0.0571
# [GPU0]     epoch 23 train batch 320/677 loss 0.0584
# [GPU0]     epoch 23 train batch 340/677 loss 0.0581
# [GPU0]     epoch 23 train batch 360/677 loss 0.0600
# [GPU0]     epoch 23 train batch 380/677 loss 0.0601
# [GPU0]     epoch 23 train batch 400/677 loss 0.0616
# [GPU0]     epoch 23 train batch 420/677 loss 0.0625
# [GPU0]     epoch 23 train batch 440/677 loss 0.0633
# [GPU0]     epoch 23 train batch 460/677 loss 0.0640
# [GPU0]     epoch 23 train batch 480/677 loss 0.0649
# [GPU0]     epoch 23 train batch 500/677 loss 0.0648
# [GPU0]     epoch 23 train batch 520/677 loss 0.0647
# [GPU0]     epoch 23 train batch 540/677 loss 0.0656
# [GPU0]     epoch 23 train batch 560/677 loss 0.0660
# [GPU0]     epoch 23 train batch 580/677 loss 0.0668
# [GPU0]     epoch 23 train batch 600/677 loss 0.0675
# [GPU0]     epoch 23 train batch 620/677 loss 0.0679
# [GPU0]     epoch 23 train batch 640/677 loss 0.0686
# [GPU0]     epoch 23 train batch 660/677 loss 0.0696
# [GPU0]     epoch 23 train batch 677/677 loss 0.0703
# [GPU0]
# [GPU0]     epoch 23 valid batch 20/83 loss 0.2340
# [GPU0]     epoch 23 valid batch 40/83 loss 0.2788
# [GPU0]     epoch 23 valid batch 60/83 loss 0.3195
# [GPU0]     epoch 23 valid batch 80/83 loss 0.3145
# [GPU0]     epoch 23 valid batch 83/83 loss 0.3103
# [GPU0]   epoch  23 train 0.0703 val 0.3103 auroc 0.6029 auprc 0.0871 accuracy 0.9042
# [GPU0]
# [GPU0]     epoch 24 train batch 20/677 loss 0.0904
# [GPU0]     epoch 24 train batch 40/677 loss 0.0773
# [GPU0]     epoch 24 train batch 60/677 loss 0.0856
# [GPU0]     epoch 24 train batch 80/677 loss 0.0815
# [GPU0]     epoch 24 train batch 100/677 loss 0.0791
# [GPU0]     epoch 24 train batch 120/677 loss 0.0812
# [GPU0]     epoch 24 train batch 140/677 loss 0.0819
# [GPU0]     epoch 24 train batch 160/677 loss 0.0806
# [GPU0]     epoch 24 train batch 180/677 loss 0.0811
# [GPU0]     epoch 24 train batch 200/677 loss 0.0805
# [GPU0]     epoch 24 train batch 220/677 loss 0.0800
# [GPU0]     epoch 24 train batch 240/677 loss 0.0802
# [GPU0]     epoch 24 train batch 260/677 loss 0.0810
# [GPU0]     epoch 24 train batch 280/677 loss 0.0808
# [GPU0]     epoch 24 train batch 300/677 loss 0.0827
# [GPU0]     epoch 24 train batch 320/677 loss 0.0832
# [GPU0]     epoch 24 train batch 340/677 loss 0.0834
# [GPU0]     epoch 24 train batch 360/677 loss 0.0846
# [GPU0]     epoch 24 train batch 380/677 loss 0.0833
# [GPU0]     epoch 24 train batch 400/677 loss 0.0836
# [GPU0]     epoch 24 train batch 420/677 loss 0.0824
# [GPU0]     epoch 24 train batch 440/677 loss 0.0817
# [GPU0]     epoch 24 train batch 460/677 loss 0.0819
# [GPU0]     epoch 24 train batch 480/677 loss 0.0805
# [GPU0]     epoch 24 train batch 500/677 loss 0.0805
# [GPU0]     epoch 24 train batch 520/677 loss 0.0806
# [GPU0]     epoch 24 train batch 540/677 loss 0.0809
# [GPU0]     epoch 24 train batch 560/677 loss 0.0800
# [GPU0]     epoch 24 train batch 580/677 loss 0.0796
# [GPU0]     epoch 24 train batch 600/677 loss 0.0785
# [GPU0]     epoch 24 train batch 620/677 loss 0.0776
# [GPU0]     epoch 24 train batch 640/677 loss 0.0768
# [GPU0]     epoch 24 train batch 660/677 loss 0.0764
# [GPU0]     epoch 24 train batch 677/677 loss 0.0758
# [GPU0]
# [GPU0]     epoch 24 valid batch 20/83 loss 0.1809
# [GPU0]     epoch 24 valid batch 40/83 loss 0.2328
# [GPU0]     epoch 24 valid batch 60/83 loss 0.3856
# [GPU0]     epoch 24 valid batch 80/83 loss 0.3736
# [GPU0]     epoch 24 valid batch 83/83 loss 0.3674
# [GPU0]   epoch  24 train 0.0758 val 0.3674 auroc 0.5349 auprc 0.0790 accuracy 0.9212
# [GPU0]
# [GPU0]     epoch 25 train batch 20/677 loss 0.0300
# [GPU0]     epoch 25 train batch 40/677 loss 0.0426
# [GPU0]     epoch 25 train batch 60/677 loss 0.0464
# [GPU0]     epoch 25 train batch 80/677 loss 0.0435
# [GPU0]     epoch 25 train batch 100/677 loss 0.0475
# [GPU0]     epoch 25 train batch 120/677 loss 0.0456
# [GPU0]     epoch 25 train batch 140/677 loss 0.0457
# [GPU0]     epoch 25 train batch 160/677 loss 0.0443
# [GPU0]     epoch 25 train batch 180/677 loss 0.0486
# [GPU0]     epoch 25 train batch 200/677 loss 0.0479
# [GPU0]     epoch 25 train batch 220/677 loss 0.0480
# [GPU0]     epoch 25 train batch 240/677 loss 0.0483
# [GPU0]     epoch 25 train batch 260/677 loss 0.0500
# [GPU0]     epoch 25 train batch 280/677 loss 0.0512
# [GPU0]     epoch 25 train batch 300/677 loss 0.0534
# [GPU0]     epoch 25 train batch 320/677 loss 0.0540
# [GPU0]     epoch 25 train batch 340/677 loss 0.0555
# [GPU0]     epoch 25 train batch 360/677 loss 0.0560
# [GPU0]     epoch 25 train batch 380/677 loss 0.0563
# [GPU0]     epoch 25 train batch 400/677 loss 0.0574
# [GPU0]     epoch 25 train batch 420/677 loss 0.0580
# [GPU0]     epoch 25 train batch 440/677 loss 0.0587
# [GPU0]     epoch 25 train batch 460/677 loss 0.0584
# [GPU0]     epoch 25 train batch 480/677 loss 0.0594
# [GPU0]     epoch 25 train batch 500/677 loss 0.0597
# [GPU0]     epoch 25 train batch 520/677 loss 0.0604
# [GPU0]     epoch 25 train batch 540/677 loss 0.0610
# [GPU0]     epoch 25 train batch 560/677 loss 0.0608
# [GPU0]     epoch 25 train batch 580/677 loss 0.0625
# [GPU0]     epoch 25 train batch 600/677 loss 0.0638
# [GPU0]     epoch 25 train batch 620/677 loss 0.0650
# [GPU0]     epoch 25 train batch 640/677 loss 0.0659
# [GPU0]     epoch 25 train batch 660/677 loss 0.0664
# [GPU0]     epoch 25 train batch 677/677 loss 0.0667
# [GPU0]
# [GPU0]     epoch 25 valid batch 20/83 loss 0.1740
# [GPU0]     epoch 25 valid batch 40/83 loss 0.2262
# [GPU0]     epoch 25 valid batch 60/83 loss 0.3323
# [GPU0]     epoch 25 valid batch 80/83 loss 0.3556
# [GPU0]     epoch 25 valid batch 83/83 loss 0.3516
# [GPU0]   epoch  25 train 0.0667 val 0.3516 auroc 0.5872 auprc 0.0863 accuracy 0.9106
# [GPU0]
# [GPU0]     epoch 26 train batch 20/677 loss 0.0731
# [GPU0]     epoch 26 train batch 40/677 loss 0.0754
# [GPU0]     epoch 26 train batch 60/677 loss 0.0758
# [GPU0]     epoch 26 train batch 80/677 loss 0.0811
# [GPU0]     epoch 26 train batch 100/677 loss 0.0783
# [GPU0]     epoch 26 train batch 120/677 loss 0.0799
# [GPU0]     epoch 26 train batch 140/677 loss 0.0817
# [GPU0]     epoch 26 train batch 160/677 loss 0.0801
# [GPU0]     epoch 26 train batch 180/677 loss 0.0792
# [GPU0]     epoch 26 train batch 200/677 loss 0.0798
# [GPU0]     epoch 26 train batch 220/677 loss 0.0793
# [GPU0]     epoch 26 train batch 240/677 loss 0.0780
# [GPU0]     epoch 26 train batch 260/677 loss 0.0760
# [GPU0]     epoch 26 train batch 280/677 loss 0.0773
# [GPU0]     epoch 26 train batch 300/677 loss 0.0764
# [GPU0]     epoch 26 train batch 320/677 loss 0.0756
# [GPU0]     epoch 26 train batch 340/677 loss 0.0753
# [GPU0]     epoch 26 train batch 360/677 loss 0.0738
# [GPU0]     epoch 26 train batch 380/677 loss 0.0758
# [GPU0]     epoch 26 train batch 400/677 loss 0.0767
# [GPU0]     epoch 26 train batch 420/677 loss 0.0764
# [GPU0]     epoch 26 train batch 440/677 loss 0.0761
# [GPU0]     epoch 26 train batch 460/677 loss 0.0759
# [GPU0]     epoch 26 train batch 480/677 loss 0.0753
# [GPU0]     epoch 26 train batch 500/677 loss 0.0748
# [GPU0]     epoch 26 train batch 520/677 loss 0.0743
# [GPU0]     epoch 26 train batch 540/677 loss 0.0739
# [GPU0]     epoch 26 train batch 560/677 loss 0.0738
# [GPU0]     epoch 26 train batch 580/677 loss 0.0729
# [GPU0]     epoch 26 train batch 600/677 loss 0.0728
# [GPU0]     epoch 26 train batch 620/677 loss 0.0721
# [GPU0]     epoch 26 train batch 640/677 loss 0.0714
# [GPU0]     epoch 26 train batch 660/677 loss 0.0714
# [GPU0]     epoch 26 train batch 677/677 loss 0.0715
# [GPU0]
# [GPU0]     epoch 26 valid batch 20/83 loss 0.2138
# [GPU0]     epoch 26 valid batch 40/83 loss 0.2409
# [GPU0]     epoch 26 valid batch 60/83 loss 0.4079
# [GPU0]     epoch 26 valid batch 80/83 loss 0.3727
# [GPU0]     epoch 26 valid batch 83/83 loss 0.3649
# [GPU0]   epoch  26 train 0.0715 val 0.3649 auroc 0.5392 auprc 0.0703 accuracy 0.9186
# [GPU0]   early stop at epoch 26 (best 11)
# [GPU0]
# [GPU0]     test batch 20/180 loss 0.1193
# [GPU0]     test batch 40/180 loss 0.2043
# [GPU0]     test batch 60/180 loss 0.2022
# [GPU0]     test batch 80/180 loss 0.1785
# [GPU0]     test batch 100/180 loss 0.1891
# [GPU0]     test batch 120/180 loss 0.1722
# [GPU0]     test batch 140/180 loss 0.1955
# [GPU0]     test batch 160/180 loss 0.1992
# [GPU0]     test batch 180/180 loss 0.1992
# [GPU0]
# [GPU0] Test metrics: {
# [GPU0]   "auroc": 0.8032264105456205,
# [GPU0]   "auprc": 0.29226635162781506,
# [GPU0]   "accuracy": 0.9333449356073791
# [GPU0] }
# [GPU0] Saved -> /kaggle/working/results/davis_cold_drug_binary_seed3_hyperattentiondti_results.json
#
# Stage 2 done

# %% [markdown]
# ## 10. What landed
#
# A cell counts as complete only when both its checkpoint and its results file exist. A
# checkpoint alone is an interrupted cell, and the next commit retrains it.

# %%
MODELS = ['deepdta', 'coldsite_dti', 'hyperattentiondti']
complete = interrupted = 0
print(f"{'model':18s} {'split':12s} {'cells':>5s}   AUROC mean +- sd")
for model in MODELS:
    for split in SPLITS:
        values = []
        for seed in SEEDS:
            ckpt = checkpoint_path(RESULTS, 'davis', split, 'binary', seed, model=model)
            res = results_path(RESULTS, run_tag('davis', split, 'binary', seed), model=model)
            if os.path.exists(ckpt) and os.path.exists(res):
                complete += 1
                values.append(json.load(open(res))['test_metrics']['auroc'])
            elif os.path.exists(ckpt):
                interrupted += 1
        spread = (f'{st.mean(values):.4f} +- {st.stdev(values):.4f}' if len(values) > 1
                  else f'{values[0]:.4f}' if values else '--')
        print(f'{model:18s} {split:12s} {len(values):>3d}/3   {spread}')

GRID_COMPLETE = complete == 36
print(f'\ncomplete    : {complete} / 36')
print(f'interrupted : {interrupted}  (retrained next commit)')
print(f'time left   : {hours_left():.1f} h')
print('\nALL 36 DONE -- analysis runs below.' if GRID_COMPLETE else
      '\nNot done yet: download the output, update the dataset, commit again with RESTORE_FROM set.')
# Out:
# model              split        cells   AUROC mean +- sd
# deepdta            random         3/3   0.9290 +- 0.0023
# deepdta            cold_drug      3/3   0.6915 +- 0.0437
# deepdta            cold_target    3/3   0.9075 +- 0.0032
# deepdta            cold_pair      3/3   0.7277 +- 0.0352
# coldsite_dti       random         3/3   0.9240 +- 0.0012
# coldsite_dti       cold_drug      3/3   0.7206 +- 0.0075
# coldsite_dti       cold_target    3/3   0.8570 +- 0.0109
# coldsite_dti       cold_pair      3/3   0.6236 +- 0.0991
# hyperattentiondti  random         3/3   0.9370 +- 0.0049
# hyperattentiondti  cold_drug      3/3   0.7602 +- 0.0416
# hyperattentiondti  cold_target    3/3   0.9148 +- 0.0015
# hyperattentiondti  cold_pair      3/3   0.6939 +- 0.0375
#
# complete    : 36 / 36
# interrupted : 0  (retrained next commit)
# time left   : 3.4 h
#
# ALL 36 DONE -- analysis runs below.

# %% [markdown]
# ## 11. Analysis — only once all 36 cells exist
#
# Faithfulness writes the accuracy file that the ladder refuses to draw without; then the
# audit table (Holm-Bonferroni once across the whole family); then the non-kinase control,
# reported with and without the cotransport-ion sites. DeepDTA is the accuracy anchor only --
# it has no attention, so it is never audited.

# %%
if not GRID_COMPLETE:
    print('Skipped: the grid is incomplete.')
elif hours_left() < 1.5:
    print(f'Skipped: {hours_left():.1f} h left is not enough. The grid is complete, so the '
          'next commit will go straight to this cell.')
else:
    GT = 'data/davis_ground_truth_sites.json'
    for seed in SEEDS:
        print(f'\n===== faithfulness + ladder, seed {seed} =====')
        # !python -m src.evaluation.run_faithfulness --dataset davis --seed {seed} --task binary \
            --checkpoint-dir {RESULTS} --results-dir {RESULTS} --out-dir {RESULTS}
        # !python -m src.evaluation.run_ladder --dataset davis --seed {seed} --task binary \
            --ground-truth {GT} --checkpoint-dir {RESULTS} --out-dir {RESULTS} \
            --accuracy-json {RESULTS}/accuracy_davis_seed{seed}.json

    print('\n===== audit grid =====')
    # !python -m src.evaluation.run_audit --models coldsite_dti,hyperattentiondti,uniform_control \
        --datasets davis --seeds 1,2,3 --task binary --ground-truth {GT} \
        --checkpoint-dir {RESULTS} --out-dir {RESULTS}

    for model in ('coldsite_dti', 'hyperattentiondti'):
        for extra in ('', '--exclude-cotransport-ions'):
            print(f'\n===== control: {model} {extra or "(all ligands)"} =====')
            # !python -m src.evaluation.run_control --model {model} --dataset davis --seed 1 \
                --task binary --checkpoint-dir {RESULTS} --out-dir {RESULTS} {extra}
# Out:
# ===== faithfulness + ladder, seed 1 =====
#
# random: measuring up to 200 pairs (17 forward passes each)
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/conv.py:370: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at /pytorch/aten/src/ATen/native/Convolution.cpp:1025.)
#   return F.conv1d(
#
# cold_drug: measuring up to 200 pairs (17 forward passes each)
#
# cold_target: measuring up to 200 pairs (17 forward passes each)
#
# cold_pair: measuring up to 200 pairs (17 forward passes each)
# Saved figure to /kaggle/working/results/faithfulness_davis_seed1.png
#
# | Level | comp. | random control | **delta** | suff. | suff. random | AOPC | n | load-bearing? |
# |---|---|---|---|---|---|---|---|---|
# | Warm | 1.1284 | 0.3575 | **0.7709** | 2.8841 | 2.8439 | 1.1627 | 200 | yes |
# | Cold-Drug | 2.0416 | 0.2167 | **1.8249** | 2.1038 | 2.4467 | 1.8593 | 200 | yes |
# | Cold-Target | 0.3073 | 0.0670 | **0.2403** | 0.6903 | 0.7403 | 0.3214 | 200 | yes |
# | Cold-Pair | 0.8037 | 0.1650 | **0.6386** | 1.3256 | 2.1913 | 0.7530 | 200 | yes |
#
# `delta` = comprehensiveness minus its random-masking control, and it is the only column that is a result. Masking anything moves the prediction, so the raw comprehensiveness means nothing on its own.
#
# `load-bearing? no` means masking the attended residues perturbed the prediction no more than masking arbitrary ones — the explanation is decoration at that level. That is a finding, not a failed run.
#
# Saved -> /kaggle/working/results/faithfulness_davis_seed1.json
# Saved -> /kaggle/working/results/faithfulness_davis_seed1.md
# Saved -> /kaggle/working/results/accuracy_davis_seed1.json   (Track C: pass to run_ladder --accuracy-json)
# Loaded ground truth for 402 usable targets
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/conv.py:370: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at /pytorch/aten/src/ATen/native/Convolution.cpp:1025.)
#   return F.conv1d(
# random: 402 proteins with usable ground truth
# cold_drug: 402 proteins with usable ground truth
# cold_target: 79 proteins with usable ground truth
# cold_pair: 79 proteins with usable ground truth
#
# | Level | precision@10 | normalised | ceiling | chance | p | n |
# |---|---|---|---|---|---|---|
# | Warm | 0.022 | 0.023 | 0.990 | 0.020 | 0.270 | 402 |
# | Cold-Drug | 0.025* | 0.025 | 0.990 | 0.020 | 0.022 | 402 |
# | Cold-Target | 0.014 | 0.014 | 0.992 | 0.019 | 0.904 | 79 |
# | Cold-Pair | 0.018 | 0.018 | 0.991 | 0.019 | 0.557 | 79 |
#
# `*` = significantly above chance (p < 0.05).
# `n` = proteins, one test pair each.
#
# Saved figure to /kaggle/working/results/headline_davis_seed1.png
# Saved -> /kaggle/working/results/ladder_davis_seed1.json
# Saved -> /kaggle/working/results/ladder_davis_seed1.md
#
# ===== faithfulness + ladder, seed 2 =====
#
# random: measuring up to 200 pairs (17 forward passes each)
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/conv.py:370: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at /pytorch/aten/src/ATen/native/Convolution.cpp:1025.)
#   return F.conv1d(
#
# cold_drug: measuring up to 200 pairs (17 forward passes each)
#
# cold_target: measuring up to 200 pairs (17 forward passes each)
#
# cold_pair: measuring up to 200 pairs (17 forward passes each)
# Saved figure to /kaggle/working/results/faithfulness_davis_seed2.png
#
# | Level | comp. | random control | **delta** | suff. | suff. random | AOPC | n | load-bearing? |
# |---|---|---|---|---|---|---|---|---|
# | Warm | 2.3442 | 0.3351 | **2.0090** | 4.4013 | 4.4377 | 2.1297 | 200 | yes |
# | Cold-Drug | 1.0604 | 0.0924 | **0.9680** | 2.0481 | 1.9452 | 1.0861 | 200 | yes |
# | Cold-Target | 1.1320 | 0.1865 | **0.9455** | 3.6394 | 4.1250 | 1.0711 | 200 | yes |
# | Cold-Pair | 1.1279 | 0.1535 | **0.9744** | 3.0154 | 3.5251 | 1.0743 | 200 | yes |
#
# `delta` = comprehensiveness minus its random-masking control, and it is the only column that is a result. Masking anything moves the prediction, so the raw comprehensiveness means nothing on its own.
#
# `load-bearing? no` means masking the attended residues perturbed the prediction no more than masking arbitrary ones — the explanation is decoration at that level. That is a finding, not a failed run.
#
# Saved -> /kaggle/working/results/faithfulness_davis_seed2.json
# Saved -> /kaggle/working/results/faithfulness_davis_seed2.md
# Saved -> /kaggle/working/results/accuracy_davis_seed2.json   (Track C: pass to run_ladder --accuracy-json)
# Loaded ground truth for 402 usable targets
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/conv.py:370: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at /pytorch/aten/src/ATen/native/Convolution.cpp:1025.)
#   return F.conv1d(
# random: 402 proteins with usable ground truth
# cold_drug: 402 proteins with usable ground truth
# cold_target: 79 proteins with usable ground truth
# cold_pair: 79 proteins with usable ground truth
#
# | Level | precision@10 | normalised | ceiling | chance | p | n |
# |---|---|---|---|---|---|---|
# | Warm | 0.009 | 0.010 | 0.990 | 0.020 | 1.000 | 402 |
# | Cold-Drug | 0.025* | 0.026 | 0.990 | 0.020 | 0.022 | 402 |
# | Cold-Target | 0.019 | 0.019 | 0.992 | 0.019 | 0.534 | 79 |
# | Cold-Pair | 0.011 | 0.011 | 0.991 | 0.019 | 0.951 | 79 |
#
# `*` = significantly above chance (p < 0.05).
# `n` = proteins, one test pair each.
#
# Saved figure to /kaggle/working/results/headline_davis_seed2.png
# Saved -> /kaggle/working/results/ladder_davis_seed2.json
# Saved -> /kaggle/working/results/ladder_davis_seed2.md
#
# ===== faithfulness + ladder, seed 3 =====
#
# random: measuring up to 200 pairs (17 forward passes each)
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/conv.py:370: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at /pytorch/aten/src/ATen/native/Convolution.cpp:1025.)
#   return F.conv1d(
#
# cold_drug: measuring up to 200 pairs (17 forward passes each)
#
# cold_target: measuring up to 200 pairs (17 forward passes each)
#
# cold_pair: measuring up to 200 pairs (17 forward passes each)
# Saved figure to /kaggle/working/results/faithfulness_davis_seed3.png
#
# | Level | comp. | random control | **delta** | suff. | suff. random | AOPC | n | load-bearing? |
# |---|---|---|---|---|---|---|---|---|
# | Warm | 1.1089 | 0.3248 | **0.7840** | 4.0776 | 4.0440 | 1.1427 | 200 | yes |
# | Cold-Drug | 1.0565 | 0.2587 | **0.7978** | 3.5181 | 3.5308 | 1.0101 | 200 | yes |
# | Cold-Target | 0.6865 | 0.1232 | **0.5633** | 1.9482 | 2.1239 | 0.7152 | 200 | yes |
# | Cold-Pair | 0.6161 | 0.1663 | **0.4498** | 1.8266 | 1.9200 | 0.5811 | 200 | yes |
#
# `delta` = comprehensiveness minus its random-masking control, and it is the only column that is a result. Masking anything moves the prediction, so the raw comprehensiveness means nothing on its own.
#
# `load-bearing? no` means masking the attended residues perturbed the prediction no more than masking arbitrary ones — the explanation is decoration at that level. That is a finding, not a failed run.
#
# Saved -> /kaggle/working/results/faithfulness_davis_seed3.json
# Saved -> /kaggle/working/results/faithfulness_davis_seed3.md
# Saved -> /kaggle/working/results/accuracy_davis_seed3.json   (Track C: pass to run_ladder --accuracy-json)
# Loaded ground truth for 402 usable targets
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/conv.py:370: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at /pytorch/aten/src/ATen/native/Convolution.cpp:1025.)
#   return F.conv1d(
# random: 402 proteins with usable ground truth
# cold_drug: 402 proteins with usable ground truth
# cold_target: 79 proteins with usable ground truth
# cold_pair: 79 proteins with usable ground truth
#
# | Level | precision@10 | normalised | ceiling | chance | p | n |
# |---|---|---|---|---|---|---|
# | Warm | 0.012 | 0.012 | 0.990 | 0.020 | 1.000 | 402 |
# | Cold-Drug | 0.013 | 0.013 | 0.990 | 0.020 | 0.999 | 402 |
# | Cold-Target | 0.019 | 0.019 | 0.992 | 0.019 | 0.484 | 79 |
# | Cold-Pair | 0.008 | 0.008 | 0.991 | 0.019 | 0.997 | 79 |
#
# `*` = significantly above chance (p < 0.05).
# `n` = proteins, one test pair each.
#
# Saved figure to /kaggle/working/results/headline_davis_seed3.png
# Saved -> /kaggle/working/results/ladder_davis_seed3.json
# Saved -> /kaggle/working/results/ladder_davis_seed3.md
#
# ===== audit grid =====
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/conv.py:370: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at /pytorch/aten/src/ATen/native/Convolution.cpp:1025.)
#   return F.conv1d(
#   coldsite_dti/davis/random/seed1: 402 proteins (40 without usable sites)
#   coldsite_dti/davis/random/seed2: 402 proteins (40 without usable sites)
#   coldsite_dti/davis/random/seed3: 402 proteins (40 without usable sites)
#   coldsite_dti/davis/cold_drug/seed1: 402 proteins (40 without usable sites)
#   coldsite_dti/davis/cold_drug/seed2: 402 proteins (40 without usable sites)
#   coldsite_dti/davis/cold_drug/seed3: 402 proteins (40 without usable sites)
#   coldsite_dti/davis/cold_target/seed1: 79 proteins (9 without usable sites)
#   coldsite_dti/davis/cold_target/seed2: 79 proteins (9 without usable sites)
#   coldsite_dti/davis/cold_target/seed3: 79 proteins (9 without usable sites)
#   coldsite_dti/davis/cold_pair/seed1: 79 proteins (9 without usable sites)
#   coldsite_dti/davis/cold_pair/seed2: 79 proteins (9 without usable sites)
#   coldsite_dti/davis/cold_pair/seed3: 79 proteins (9 without usable sites)
#   hyperattentiondti/davis/random/seed1: 402 proteins (40 without usable sites)
#   hyperattentiondti/davis/random/seed2: 402 proteins (40 without usable sites)
#   hyperattentiondti/davis/random/seed3: 402 proteins (40 without usable sites)
#   hyperattentiondti/davis/cold_drug/seed1: 402 proteins (40 without usable sites)
#   hyperattentiondti/davis/cold_drug/seed2: 402 proteins (40 without usable sites)
#   hyperattentiondti/davis/cold_drug/seed3: 402 proteins (40 without usable sites)
#   hyperattentiondti/davis/cold_target/seed1: 79 proteins (9 without usable sites)
#   hyperattentiondti/davis/cold_target/seed2: 79 proteins (9 without usable sites)
#   hyperattentiondti/davis/cold_target/seed3: 79 proteins (9 without usable sites)
#   hyperattentiondti/davis/cold_pair/seed1: 79 proteins (9 without usable sites)
#   hyperattentiondti/davis/cold_pair/seed2: 79 proteins (9 without usable sites)
#   hyperattentiondti/davis/cold_pair/seed3: 79 proteins (9 without usable sites)
#   uniform_control/davis/random/seed1: 402 proteins (40 without usable sites)
#   uniform_control/davis/random/seed2: 402 proteins (40 without usable sites)
#   uniform_control/davis/random/seed3: 402 proteins (40 without usable sites)
#   uniform_control/davis/cold_drug/seed1: 402 proteins (40 without usable sites)
#   uniform_control/davis/cold_drug/seed2: 402 proteins (40 without usable sites)
#   uniform_control/davis/cold_drug/seed3: 402 proteins (40 without usable sites)
#   uniform_control/davis/cold_target/seed1: 79 proteins (9 without usable sites)
#   uniform_control/davis/cold_target/seed2: 79 proteins (9 without usable sites)
#   uniform_control/davis/cold_target/seed3: 79 proteins (9 without usable sites)
#   uniform_control/davis/cold_pair/seed1: 79 proteins (9 without usable sites)
#   uniform_control/davis/cold_pair/seed2: 79 proteins (9 without usable sites)
#   uniform_control/davis/cold_pair/seed3: 79 proteins (9 without usable sites)
# # Audit grid
#
# | Model | Warm | Cold-Drug | Cold-Target | Cold-Pair | Drop |
# |---|---|---|---|---|---|
# | coldsite_dti | 0.015 ± 0.006 | 0.021 ± 0.006 | 0.017 ± 0.003 | 0.012 ± 0.005 | +0.002 |
# | hyperattentiondti | 0.033 ± 0.006 | 0.041 ± 0.034 | 0.024 ± 0.006 | 0.022 ± 0.011 | +0.011 |
# | uniform_control | 0.020 ± 0.002 | 0.020 ± 0.001 | 0.021 ± 0.011 | 0.019 ± 0.004 | +0.001 |
#
# `±` is the standard deviation over seeds. `!` marks a cell with fewer than 3 seeds — not a usable estimate.
#
# ## Significance (Holm-Bonferroni over the whole grid)
#
# 1 of 12 cells survive correction at alpha = 0.05.
#
# - `hyperattentiondti|davis|random` p=0.001996 (threshold 0.004167) -> yes
# - `coldsite_dti|davis|cold_drug` p=0.03393 (threshold 0.004545) -> no
# - `hyperattentiondti|davis|cold_target` p=0.05988 (threshold 0.005) -> no
# - `hyperattentiondti|davis|cold_drug` p=0.08782 (threshold 0.005556) -> no
# - `uniform_control|davis|cold_target` p=0.0978 (threshold 0.00625) -> no
# - `hyperattentiondti|davis|cold_pair` p=0.3154 (threshold 0.007143) -> no
# - `coldsite_dti|davis|cold_target` p=0.5329 (threshold 0.008333) -> no
# - `uniform_control|davis|cold_pair` p=0.5509 (threshold 0.01) -> no
# - `uniform_control|davis|cold_drug` p=0.5569 (threshold 0.0125) -> no
# - `uniform_control|davis|random` p=0.6786 (threshold 0.01667) -> no
# - `coldsite_dti|davis|cold_pair` p=0.9741 (threshold 0.025) -> no
# - `coldsite_dti|davis|random` p=1 (threshold 0.05) -> no
#
# ## Confound control (kinase vs non-kinase)
#
# **No stratified comparison was possible.** Fewer than 20 non-kinase targets were available in every cell. The unstratified ladder must NOT be presented as if the kinase confound were absent -- state it as an explicit limitation in the Discussion, or enlarge the antiviral subset (Track A, Priority 1).
#
# ===== control: coldsite_dti (all ligands) =====
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/conv.py:370: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at /pytorch/aten/src/ATen/native/Convolution.cpp:1025.)
#   return F.conv1d(
# # Kinase confound control — coldsite_dti, davis, seed 1
#
# The non-kinase arm is a **transfer** condition, not a stratification: 60 BindingDB proteins that no model trained on this dataset has seen, with their own UniProt binding-site annotation. It is therefore harder than this dataset's own cold_target level, where the protein is unseen but still a kinase.
#
# | Level | kinase p@10 | non-kinase p@10 | gap | kinase n | non-kinase n |
# |---|---|---|---|---|---|
# | random | 0.022 | 0.008 | +0.013 | 402 | 60 |
# | cold_drug | 0.025* | 0.013 | +0.011 | 402 | 60 |
# | cold_target | 0.014 | 0.008 | +0.006 | 79 | 60 |
# | cold_pair | 0.018 | 0.060* | -0.042 | 79 | 60 |
#
# `*` = significant before correction. Correct across the whole grid with `run_audit`, not per cell.
#
# Control arm: **60 distinct non-kinase targets**, `control_is_usable: True`.
#
# Saved -> /kaggle/working/results/control_coldsite_dti_davis_seed1.{json,md}
#
# ===== control: coldsite_dti --exclude-cotransport-ions =====
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/conv.py:370: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at /pytorch/aten/src/ATen/native/Convolution.cpp:1025.)
#   return F.conv1d(
# # Kinase confound control — coldsite_dti, davis, seed 1
#
# The non-kinase arm is a **transfer** condition, not a stratification: 60 BindingDB proteins that no model trained on this dataset has seen, with their own UniProt binding-site annotation. It is therefore harder than this dataset's own cold_target level, where the protein is unseen but still a kinase.
#
# | Level | kinase p@10 | non-kinase p@10 | gap | kinase n | non-kinase n |
# |---|---|---|---|---|---|
# | random | 0.022 | 0.008 | +0.013 | 402 | 60 |
# | cold_drug | 0.025* | 0.013 | +0.011 | 402 | 60 |
# | cold_target | 0.014 | 0.005 | +0.009 | 79 | 60 |
# | cold_pair | 0.018 | 0.060* | -0.042 | 79 | 60 |
#
# `*` = significant before correction. Correct across the whole grid with `run_audit`, not per cell.
#
# Control arm: **60 distinct non-kinase targets**, `control_is_usable: True`.
#
# Saved -> /kaggle/working/results/control_coldsite_dti_davis_seed1_noions.{json,md}
#
# ===== control: hyperattentiondti (all ligands) =====
# # Kinase confound control — hyperattentiondti, davis, seed 1
#
# The non-kinase arm is a **transfer** condition, not a stratification: 60 BindingDB proteins that no model trained on this dataset has seen, with their own UniProt binding-site annotation. It is therefore harder than this dataset's own cold_target level, where the protein is unseen but still a kinase.
#
# | Level | kinase p@10 | non-kinase p@10 | gap | kinase n | non-kinase n |
# |---|---|---|---|---|---|
# | random | 0.032* | 0.015 | +0.017 | 402 | 60 |
# | cold_drug | 0.023 | 0.020 | +0.003 | 402 | 60 |
# | cold_target | 0.018 | 0.017 | +0.001 | 79 | 60 |
# | cold_pair | 0.011 | 0.007 | +0.005 | 79 | 60 |
#
# `*` = significant before correction. Correct across the whole grid with `run_audit`, not per cell.
#
# Control arm: **60 distinct non-kinase targets**, `control_is_usable: True`.
#
# Saved -> /kaggle/working/results/control_hyperattentiondti_davis_seed1.{json,md}
#
# ===== control: hyperattentiondti --exclude-cotransport-ions =====
# # Kinase confound control — hyperattentiondti, davis, seed 1
#
# The non-kinase arm is a **transfer** condition, not a stratification: 60 BindingDB proteins that no model trained on this dataset has seen, with their own UniProt binding-site annotation. It is therefore harder than this dataset's own cold_target level, where the protein is unseen but still a kinase.
#
# | Level | kinase p@10 | non-kinase p@10 | gap | kinase n | non-kinase n |
# |---|---|---|---|---|---|
# | random | 0.032* | 0.015 | +0.017 | 402 | 60 |
# | cold_drug | 0.023 | 0.017 | +0.006 | 402 | 60 |
# | cold_target | 0.018 | 0.017 | +0.001 | 79 | 60 |
# | cold_pair | 0.011 | 0.007 | +0.005 | 79 | 60 |
#
# `*` = significant before correction. Correct across the whole grid with `run_audit`, not per cell.
#
# Control arm: **60 distinct non-kinase targets**, `control_is_usable: True`.
#
# Saved -> /kaggle/working/results/control_hyperattentiondti_davis_seed1_noions.{json,md}

# %% [markdown]
# ## 12. Take the results with you
#
# Everything in `/kaggle/working` is saved as this version's output. The zip is the easy
# download. Add its contents to your restore dataset (as a new version) before the next
# commit, and keep a copy in Google Drive -- the checkpoints are what the analysis reads, and
# retraining them costs the whole grid again.

# %%
# !cd {WORK} && rm -f grid36_results.zip && zip -qr grid36_results.zip results
print(f'{WORK}/grid36_results.zip  --  download from the Output panel')
# Out:
# /kaggle/working/grid36_results.zip  --  download from the Output panel
